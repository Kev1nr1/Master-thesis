# %%
import pandas as pd

df = pd.read_csv('datasets/labeled_vulnerabilities.csv', index_col=0)
df
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_28852\246118412.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('datasets/labeled_vulnerabilities.csv', index_col=0)
#                                                        description  \
# id
# EUVD-2026-24141  FreeScout is a free self-hosted help desk and ...
# EUVD-2026-24138  Vulnerability related to an unquoted search pa...
# EUVD-2026-24136  The method "sock_recvfrom_into()" of "asyncio....
# EUVD-2026-24130  User‑Controlled HTTP Header in Fortra's GoAnyw...
# EUVD-2026-24129  The login limit is not enforced on the SFTP se...
# ...                                                            ...
# EUVD-2024-36450  Dell Peripheral Manager, versions prior to 1.7...
# EUVD-2024-47512  The Slider by 10Web  WordPress plugin before 1...
# EUVD-2024-48252  A vulnerability was found in code-projects Onl...
# EUVD-2024-48251  A vulnerability was found in SourceCodester Re...
# EUVD-2024-48260  A vulnerability classified as critical has bee...
#
#                              datePublished               dateUpdated  \
# id
# EUVD-2026-24141   Apr 21, 2026, 3:52:39 PM  Apr 21, 2026, 3:52:39 PM
# EUVD-2026-24138   Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM
# EUVD-2026-24136   Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM
# EUVD-2026-24130   Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM
# EUVD-2026-24129   Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM
# ...                                    ...                       ...
# EUVD-2024-36450   Jul 31, 2024, 8:25:10 AM  Jul 31, 2024, 1:53:39 PM
# EUVD-2024-47512   Jul 31, 2024, 6:00:03 AM  Jul 31, 2024, 1:30:13 PM
# EUVD-2024-48252  Jul 31, 2024, 10:31:04 AM  Jul 31, 2024, 1:29:51 PM
# EUVD-2024-48251  Jul 31, 2024, 10:00:07 AM  Jul 31, 2024, 1:13:05 PM
# EUVD-2024-48260  Jul 31, 2024, 11:00:08 AM  Jul 31, 2024, 1:05:37 PM
#
#                  baseScoreVersion exploitedSince  \
# id
# EUVD-2026-24141               3.1            NaN
# EUVD-2026-24138               4.0            NaN
# EUVD-2026-24136               4.0            NaN
# EUVD-2026-24130               3.1            NaN
# EUVD-2026-24129               3.1            NaN
# ...                           ...            ...
# EUVD-2024-36450               3.1            NaN
# EUVD-2024-47512               3.1            NaN
# EUVD-2024-48252               4.0            NaN
# EUVD-2024-48251               4.0            NaN
# EUVD-2024-48260               4.0            NaN
#
#                                                    baseScoreVector  epss  \
# id
# EUVD-2026-24141       CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N  0.00
# EUVD-2026-24138  CVSS:4.0/AV:L/AC:L/AT:N/PR:L/UI:N/VC:H/VI:H/VA...  0.00
# EUVD-2026-24136  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...  0.00
# EUVD-2026-24130       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:L  0.00
# EUVD-2026-24129       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:L/A:L  0.00
# ...                                                            ...   ...
# EUVD-2024-36450       CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  0.10
# EUVD-2024-47512       CVSS:3.1/AV:N/AC:L/PR:L/UI:R/S:C/C:L/I:L/A:N  0.39
# EUVD-2024-48252  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...  0.11
# EUVD-2024-48251  CVSS:4.0/AV:N/AC:L/AT:N/PR:L/UI:N/VC:N/VI:L/VA...  0.13
# EUVD-2024-48260  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...  0.25
#
#                  assigner                                aliases  \
# id
# EUVD-2026-24141  GitHub_M                       CVE-2026-40565\n
# EUVD-2026-24138    INCIBE   GHSA-9vxj-j2f7-9mgg\nCVE-2026-5789\n
# EUVD-2026-24136       PSF   GHSA-3p9c-22jr-wq4x\nCVE-2026-3298\n
# EUVD-2026-24130    Fortra   GHSA-6x5f-r479-qh4p\nCVE-2026-1089\n
# EUVD-2026-24129    Fortra   GHSA-rpc6-m3h5-gmf2\nCVE-2026-0972\n
# ...                   ...                                    ...
# EUVD-2024-36450      dell  CVE-2024-37127\nGHSA-xqvw-7hh9-jm8v\n
# EUVD-2024-47512    WPScan   GHSA-rh6j-hw6c-hv3x\nCVE-2024-6408\n
# EUVD-2024-48252     VulDB   CVE-2024-7311\nGHSA-qpfv-2pqx-cqjq\n
# EUVD-2024-48251     VulDB   CVE-2024-7310\nGHSA-8235-8498-xmmj\n
# EUVD-2024-48260     VulDB   GHSA-w2gr-9pwc-5pm2\nCVE-2024-7320\n
#
#                                                      enisaIdVendor  \
# id
# EUVD-2026-24141  [{'id': 'df8ea7fe-ea1b-3f31-a494-89b12dbf0c16'...
# EUVD-2026-24138  [{'id': '5112208e-9449-3f30-b5a0-bdefa26b6740'...
# EUVD-2026-24136  [{'id': '455eddad-0274-38e3-876c-1da485aedea5'...
# EUVD-2026-24130  [{'id': '2ae1e1ad-e03a-3855-b5d6-a2176c0b31dd'...
# EUVD-2026-24129  [{'id': 'cba00c9f-fa23-3062-a6a5-5709e85421d7'...
# ...                                                            ...
# EUVD-2024-36450  [{'id': '30cd5f39-c87b-358f-91f7-468c03678ac8'...
# EUVD-2024-47512  [{'id': '40176e2c-1188-395c-b64a-949454bdd148'...
# EUVD-2024-48252  [{'id': 'd105cdc5-5c97-380f-88c9-160c2abf6996'...
# EUVD-2024-48251  [{'id': 'ef82b568-394a-3b11-a35a-0b0cf37659e4'...
# EUVD-2024-48260  [{'id': '290163b4-67c5-33a8-9f6e-eb813d7f879e'...
#
#                                                         references  \
# id
# EUVD-2026-24141  https://github.com/freescout-help-desk/freesco...
# EUVD-2026-24138  https://www.incibe.es/en/incibe-cert/notices/a...
# EUVD-2026-24136  https://github.com/python/cpython/pull/148809\...
# EUVD-2026-24130  https://www.fortra.com/security/advisories/pro...
# EUVD-2026-24129  https://fortra.com/security/advisories/product...
# ...                                                            ...
# EUVD-2024-36450  https://www.dell.com/support/kbdoc/en-us/00022...
# EUVD-2024-47512  https://wpscan.com/vulnerability/31aaeffb-a752...
# EUVD-2024-48252  https://vuldb.com/?id.273203\nhttps://vuldb.co...
# EUVD-2024-48251  https://vuldb.com/?id.273202\nhttps://vuldb.co...
# EUVD-2024-48260  https://vuldb.com/?id.273231\nhttps://vuldb.co...
#
#                                                     enisaIdProduct  baseScore  \
# id
# EUVD-2026-24141  [{'id': '35cc8fe9-cc82-3bc7-9dda-d8dfd8a9d826'...        6.1
# EUVD-2026-24138  [{'id': '4dd00402-1cb8-33d1-91f8-5daf0e5fa5c5'...        8.5
# EUVD-2026-24136  [{'id': '79323943-f5b6-3a59-ac3e-e7849e5be63e'...        8.8
# EUVD-2026-24130  [{'id': '70404ca1-7e53-3be1-87b1-6dc09b1e4ff2'...        6.5
# EUVD-2026-24129  [{'id': 'd104a637-0939-344c-be4c-448beede3920'...        7.3
# ...                                                            ...        ...
# EUVD-2024-36450  [{'id': '7c62f44e-50d1-3074-a5dd-373708eade30'...        7.8
# EUVD-2024-47512  [{'id': '5bf633bc-747a-3491-9d94-4e46605d9307'...        5.4
# EUVD-2024-48252  [{'id': 'c549f477-2c72-31c2-b424-d8f8f60abcdc'...        6.9
# EUVD-2024-48251  [{'id': '61098927-59a9-3abb-b147-dddb86706f6c'...        5.3
# EUVD-2024-48260  [{'id': '48228bfe-9c8e-313e-8ade-203448cbb398'...        6.9
#
#                                             enisaUuid  \
# id
# EUVD-2026-24141  b3a6ee31-e20e-3b1c-a684-768095acc098
# EUVD-2026-24138  7ed70757-c092-3a0b-99e2-96a7f815201b
# EUVD-2026-24136  e0f49fce-f7e8-3dfc-b70e-dbc0c058a383
# EUVD-2026-24130  f1bfb170-4572-33bb-a02c-83c7a5e4ce08
# EUVD-2026-24129  3965ce35-f611-3fd6-bc4c-580538b77705
# ...                                               ...
# EUVD-2024-36450  f8927bdc-f7c7-3b9a-bc2b-c1dfd1745b43
# EUVD-2024-47512  dd4b7636-4bc4-3bbf-96ad-0ef437c43e68
# EUVD-2024-48252  3f64fe34-85d0-3e95-89c9-660b978e5604
# EUVD-2024-48251  d1e6b715-fd3f-3e88-97ef-66e862d47d64
# EUVD-2024-48260  954603d9-6741-357c-93a6-40c28ff13d29
#
#                                                description_cleaned  \
# id
# EUVD-2026-24141  ['freescout', 'free', 'selfhosted', 'help', 'd...
# EUVD-2026-24138  ['vulnerability', 'related', 'unquoted', 'sear...
# EUVD-2026-24136  ['method', 'sock_recvfrom_into', 'asyncioproac...
# EUVD-2026-24130  ['usercontrolled', 'http', 'header', 'fortras'...
# EUVD-2026-24129  ['login', 'limit', 'enforced', 'sftp', 'servic...
# ...                                                            ...
# EUVD-2024-36450  ['dell', 'peripheral', 'manager', 'version', '...
# EUVD-2024-47512  ['slider', '10web', 'wordpress', 'plugin', '12...
# EUVD-2024-48252  ['vulnerability', 'wa', 'found', 'codeprojects...
# EUVD-2024-48251  ['vulnerability', 'wa', 'found', 'sourcecodest...
# EUVD-2024-48260  ['vulnerability', 'classified', 'critical', 'h...
#
#                                         product_name  \
# id
# EUVD-2026-24141                            freescout
# EUVD-2026-24138                             civetweb
# EUVD-2026-24136                              CPython
# EUVD-2026-24130                       GoAnywhere MFT
# EUVD-2026-24129                       GoAnywhere MFT
# ...                                              ...
# EUVD-2024-36450              Dell Peripheral Manager
# EUVD-2024-47512                      Slider by 10Web
# EUVD-2024-48252          Online Bus Reservation Site
# EUVD-2024-48251             Record Management System
# EUVD-2024-48260  Online Blood Bank Management System
#
#                                 vendor_name  \
# id
# EUVD-2026-24141         freescout-help-desk
# EUVD-2026-24138                    CivetWeb
# EUVD-2026-24136  Python Software Foundation
# EUVD-2026-24130                      Fortra
# EUVD-2026-24129                      Fortra
# ...                                     ...
# EUVD-2024-36450                        Dell
# EUVD-2024-47512                     Unknown
# EUVD-2024-48252               code-projects
# EUVD-2024-48251              SourceCodester
# EUVD-2024-48260                itsourcecode
#
#                                                      product_label
# id
# EUVD-2026-24141              Customer Support & Help Desk Software
# EUVD-2026-24138                                Web Server Software
# EUVD-2026-24136       Programming Language Runtimes & Interpreters
# EUVD-2026-24130               FTP & Managed File Transfer Software
# EUVD-2026-24129               FTP & Managed File Transfer Software
# ...                                                            ...
# EUVD-2024-36450            IT Asset & Endpoint Management Software
# EUVD-2024-47512           WordPress / WooCommerce Plugins & Themes
# EUVD-2024-48252      Booking & Reservation Systems (Non-WordPress)
# EUVD-2024-48251                       Document Management Software
# EUVD-2024-48260  Electronic Health Record & Healthcare Manageme...
#
# [130193 rows x 18 columns]

# %%
from scipy.stats import kruskal

groups_epss = [
    group["epss"].dropna().values
    for _, group in df.groupby("product_label")
]

stat, p = kruskal(*groups_epss)

print(f"H = {stat:.3f}")
print(f"p = {p:.5f}")

groups_cvss = [
    group["baseScore"].dropna().values
    for _, group in df.groupby("product_label")
]

stat, p = kruskal(*groups_cvss)

print(f"H = {stat:.3f}")
print(f"p = {p:.5f}")
# Out:
# H = 7250.029
# p = 0.00000
# H = 7954.899
# p = 0.00000

# %%
n = len(df)
k = df["product_label"].nunique()

def epsilon_squared(H, n):
    return H / (n - 1)

eps_epss = epsilon_squared(7250.029, n)
eps_cvss = epsilon_squared(7954.899, n)

print(f"EPSS effect size (epsilon^2): {eps_epss:.4f}")
print(f"CVSS effect size (epsilon^2): {eps_cvss:.4f}")
# Out:
# EPSS effect size (epsilon^2): 0.0557
# CVSS effect size (epsilon^2): 0.0611

# %%
group_sizes = df.groupby("product_label")["epss"].count().sort_values()
print("15 smallest groups:")
print(group_sizes.sort_values().head(15))

print("\n15 largest groups:")
print(group_sizes.sort_values(ascending=False).head(15))
# Out:
# 15 smallest groups:
# product_label
# General Software Applications                        24
# Mobile Device Hardware & Firmware                    36
# Laboratory & Scientific Instrumentation              77
# Social Media Management & Integration Tools          97
# Medical Devices & Diagnostic Equipment              106
# Website Builders & Templates                        108
# Web Scraping & Data Extraction Tools                116
# Unclassified / Other                                127
# Secure Shell & Remote Administration Tools          144
# Data Serialization, Parsing & Encoding Libraries    163
# AI Writing, Content & Code Assistant Tools          165
# Automotive & Vehicle Systems                        186
# Government, Nonprofit & Public Sector Systems       193
# DNS, Proxy & Network Privacy Tools                  201
# Hardware & Electronics (General/Unclassified)       203
# Name: epss, dtype: int64
#
# 15 largest groups:
# product_label
# WordPress / WooCommerce Plugins & Themes                  23001
# Operating Systems                                         12718
# Networking Hardware (Routers, Switches, Access Points)     4820
# General CMS Platforms (Non-WordPress)                      3407
# Software Development Libraries & SDKs                      3245
# Network Security & Firewall Software                       2597
# System-on-Chip, Processors & Semiconductor Components      2426
# Identity & Access Management / Authentication Software     2322
# IT Infrastructure & Server Management Software             2316
# Database Management Software                               2252
# Image, Photo & Video Editing Software                      2184
# Artificial Intelligence & Machine Learning Software        2161
# Industrial Control Systems & PLCs                          2125
# Learning Management & Educational Software                 2090
# Web Browsers & Extensions                                  2020
# Name: epss, dtype: int64

# %%
# Rank product labels by central tendency for EPSS
epss_rank = df.groupby("product_label")["epss"].agg(["median", "mean", "count"]).sort_values("median", ascending=True)
print("Top 15 product labels by EPSS:")
print(epss_rank.head(15))

# Rank product labels by central tendency for CVSS base score
cvss_rank = df.groupby("product_label")["baseScore"].agg(["median", "mean", "count"]).sort_values("median", ascending=True)
print("\nTop 15 product labels by CVSS base score:")
print(cvss_rank.head(15))
# Out:
# Top 15 product labels by EPSS:
#                                                     median      mean  count
# product_label
# Gaming Software & Game Engines                        0.05  0.601568    472
# Wearable & Consumer Electronics                       0.05  0.322866    984
# System-on-Chip, Processors & Semiconductor Comp...    0.05  0.239588   2426
# Automotive & Vehicle Systems                          0.06  0.239731    186
# Mobile Device Hardware & Firmware                     0.06  0.141389     36
# Hardware & Electronics (General/Unclassified)         0.06  0.240049    203
# System Administration & Scripting Tools               0.07  1.509425    818
# Inventory & Supply Chain Management Software          0.08  0.684231    624
# Physical Access Control & Security Hardware           0.08  0.597740    354
# Operating Systems                                     0.08  2.121991  12718
# Cryptography, Encryption & PKI Software               0.08  1.165379    805
# Real Estate & Property Management Software            0.08  0.321084    286
# Government, Nonprofit & Public Sector Systems         0.09  0.270725    193
# Laboratory & Scientific Instrumentation               0.09  0.490390     77
# Medical Devices & Diagnostic Equipment                0.09  0.254811    106
#
# Top 15 product labels by CVSS base score:
#                                                     median      mean  count
# product_label
# Real Estate & Property Management Software             5.3  5.920979    286
# Legal, Compliance & Privacy Management Software        5.4  6.030000    210
# Web Forums & Discussion Platforms                      5.4  5.902317    561
# General CMS Platforms (Non-WordPress)                  5.4  6.001790   3407
# Mobile Applications (Android/iOS)                      5.5  5.885466    633
# Wearable & Consumer Electronics                        5.5  5.619919    984
# Version Control & Source Code Management Tools         5.8  5.880419   1241
# Messaging & Chat Applications                          5.8  6.058637    411
# Enterprise Software (General Business Applicati...     5.9  6.114137    771
# Database Management Software                           5.9  6.121980   2252
# Programming Language Runtimes & Interpreters           5.9  5.837688    597
# Security Information & Vulnerability Management...     5.9  5.949151   1591
# Government, Nonprofit & Public Sector Systems          6.1  6.135233    193
# Inventory & Supply Chain Management Software           6.1  6.193910    624
# Application Server / Middleware                        6.1  6.344875   1083

# %%
# Rank product labels by central tendency for EPSS
epss_rank = df.groupby("product_label")["epss"].agg(["median", "mean", "count"]).sort_values("median", ascending=False)
print("Top 15 product labels by EPSS:")
print(epss_rank.head(15))

# Rank product labels by central tendency for CVSS base score
cvss_rank = df.groupby("product_label")["baseScore"].agg(["median", "mean", "count"]).sort_values("median", ascending=False)
print("\nTop 15 product labels by CVSS base score:")
print(cvss_rank.head(15))
# Out:
# Top 15 product labels by EPSS:
#                                                     median      mean  count
# product_label
# PDF & Document Viewer/Editor Software                0.680  3.331705   1132
# Web Server Software                                  0.310  5.988652    282
# Networking Hardware (Routers, Switches, Access ...   0.290  1.686071   4820
# Wiki & Knowledge Base Software                       0.260  4.351299    970
# Document Management Software                         0.260  2.389028   1739
# Blockchain & Cryptocurrency Software                 0.240  1.247721    294
# FTP & Managed File Transfer Software                 0.240  6.066998    563
# Web Browsers & Extensions                            0.230  2.337827   2020
# VoIP & Telephony Systems                             0.230  3.186700    500
# Reverse Proxy & Load Balancer Software               0.225  3.545974    616
# Penetration Testing & Security Assessment Tools      0.220  2.549525    316
# Database Management Software                         0.220  2.094574   2252
# Application Server / Middleware                      0.220  4.925623   1083
# Email & Messaging Server Software                    0.210  6.488896    634
# Email Security & Anti-Spam Software                  0.210  2.944012    324
#
# Top 15 product labels by CVSS base score:
#                                                     median      mean  count
# product_label
# Power, Energy & Electrical Equipment                   8.1  7.714286    469
# Manufacturing Execution Systems & Engineering S...     7.8  7.403254   1045
# PDF & Document Viewer/Editor Software                  7.8  6.651060   1132
# Image, Photo & Video Editing Software                  7.8  6.973397   2184
# Networking Hardware (Routers, Switches, Access ...     7.7  7.515353   4820
# Industrial Control Systems & PLCs                      7.6  7.416282   2125
# Physical Access Control & Security Hardware            7.5  7.333333    354
# Industrial Automation Hardware & Equipment             7.5  7.457479    849
# Building Management & Automation Systems               7.5  7.372461    512
# Productivity & Office Software                         7.5  6.908379   1277
# System-on-Chip, Processors & Semiconductor Comp...     7.5  6.748599   2426
# Web Browsers & Extensions                              7.5  6.723911   2020
# Video Surveillance & Security Camera Systems           7.5  7.284852    779
# DNS, Proxy & Network Privacy Tools                     7.5  6.621891    201
# Integrated Development Environments (IDEs) & Co...     7.4  6.872247    663

# %%
import scikit_posthocs as sp

import numpy as np

dunn_epss = sp.posthoc_dunn(df, val_col="epss", group_col="product_label", p_adjust="holm")

# Flatten the matrix into pairwise comparisons
mask = np.triu(np.ones(dunn_epss.shape), k=1).astype(bool)
results_flat = dunn_epss.where(mask).stack().reset_index()
results_flat.columns = ["group1", "group2", "p_adj"]
results_flat = results_flat.sort_values("p_adj").reset_index(drop=True)

# Significant pairs only
sig_pairs = results_flat[results_flat["p_adj"] < 0.05]


import pandas as pd

appearance_counts = pd.concat([sig_pairs["group1"], sig_pairs["group2"]]).value_counts()
print(appearance_counts)
# Out:
# PDF & Document Viewer/Editor Software                     99
# System-on-Chip, Processors & Semiconductor Components     93
# Wearable & Consumer Electronics                           93
# Gaming Software & Game Engines                            90
# Networking Hardware (Routers, Switches, Access Points)    88
#                                                           ..
# Website Builders & Templates                              11
# Laboratory & Scientific Instrumentation                   10
# Mobile Device Hardware & Firmware                          9
# Web Scraping & Data Extraction Tools                       7
# Social Media Management & Integration Tools                6
# Name: count, Length: 100, dtype: int64

# %%
dunn_cvss = sp.posthoc_dunn(df, val_col="baseScore", group_col="product_label", p_adjust="holm")

mask = np.triu(np.ones(dunn_cvss.shape), k=1).astype(bool)
cvss_flat = dunn_cvss.where(mask).stack().reset_index()
cvss_flat.columns = ["group1", "group2", "p_adj"]
cvss_flat = cvss_flat.sort_values("p_adj").reset_index(drop=True)

sig_pairs_cvss = cvss_flat[cvss_flat["p_adj"] < 0.05]
appearance_counts_cvss = pd.concat([sig_pairs_cvss["group1"], sig_pairs_cvss["group2"]]).value_counts()
print(appearance_counts_cvss)
# Out:
# Manufacturing Execution Systems & Engineering Software    89
# Power, Energy & Electrical Equipment                      89
# Networking Hardware (Routers, Switches, Access Points)    88
# Wearable & Consumer Electronics                           85
# Industrial Control Systems & PLCs                         83
#                                                           ..
# Web Scraping & Data Extraction Tools                      13
# Secure Shell & Remote Administration Tools                12
# Social Media Management & Integration Tools               11
# Website Builders & Templates                               9
# Laboratory & Scientific Instrumentation                    3
# Name: count, Length: 99, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, max(6, df["product_label"].nunique())))

# Boxenplot behaves like a boxplot but handles heavy tails beautifully
sns.boxenplot(data=df, x="epss", y="product_label", orient="h")

plt.title("EPSS Boxenplot Distribution by Product Label", fontsize=14)
plt.xlabel("EPSS Score")
plt.ylabel("Product Label")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, max(6, df["product_label"].nunique())))
sns.boxenplot(data=df, x="baseScore", y="product_label", orient="h")
plt.title("CVSS Base Score Boxenplot Distribution by Product Label", fontsize=14)
plt.xlabel("CVSS Base Score")
plt.ylabel("Product Label")
plt.tight_layout()
plt.show()

# %%
summary = df.groupby("product_label")["epss"].agg(["median", lambda x: x.quantile(0.75) - x.quantile(0.25)])
summary.columns = ["Median", "IQR"]
print(summary)
# Out:
#                                                     Median     IQR
# product_label
# AI Writing, Content & Code Assistant Tools           0.090  0.1800
# API & Integration Tools                              0.145  0.2625
# Accounting & Financial Management Software           0.140  0.2300
# Application Server / Middleware                      0.220  0.4900
# Artificial Intelligence & Machine Learning Soft...   0.110  0.2700
# ...                                                    ...     ...
# Web Scraping & Data Extraction Tools                 0.120  0.3000
# Web Server Software                                  0.310  0.6550
# Website Builders & Templates                         0.110  0.1700
# Wiki & Knowledge Base Software                       0.260  0.7375
# WordPress / WooCommerce Plugins & Themes             0.140  0.2000
#
# [101 rows x 2 columns]

# %%
medians = df.groupby("product_label")["epss"].median()

top_pairs = sig_pairs.copy()
top_pairs["median_group1"] = top_pairs["group1"].map(medians)
top_pairs["median_group2"] = top_pairs["group2"].map(medians)
top_pairs["diff"] = (top_pairs["median_group1"] - top_pairs["median_group2"]).abs()

top_pairs.sort_values("diff", ascending=False).head(15)
# Out:
#                                              group1  \
# 22                   Gaming Software & Game Engines
# 4             PDF & Document Viewer/Editor Software
# 2             PDF & Document Viewer/Editor Software
# 1124              Mobile Device Hardware & Firmware
# 158                    Automotive & Vehicle Systems
# 159   Hardware & Electronics (General/Unclassified)
# 29            PDF & Document Viewer/Editor Software
# 61     Inventory & Supply Chain Management Software
# 34          Cryptography, Encryption & PKI Software
# 169           PDF & Document Viewer/Editor Software
# 7                                 Operating Systems
# 138           PDF & Document Viewer/Editor Software
# 581          Medical Devices & Diagnostic Equipment
# 14       Learning Management & Educational Software
# 241   Government, Nonprofit & Public Sector Systems
#
#                                                  group2          p_adj  \
# 22                PDF & Document Viewer/Editor Software  3.322381e-155
# 4                       Wearable & Consumer Electronics  2.742287e-249
# 2     System-on-Chip, Processors & Semiconductor Com...   0.000000e+00
# 1124              PDF & Document Viewer/Editor Software   1.615412e-09
# 158               PDF & Document Viewer/Editor Software   5.375809e-63
# 159               PDF & Document Viewer/Editor Software   7.036014e-63
# 29              System Administration & Scripting Tools  3.105583e-135
# 61                PDF & Document Viewer/Editor Software  1.723901e-100
# 34                PDF & Document Viewer/Editor Software  1.656414e-125
# 169          Real Estate & Property Management Software   1.122108e-58
# 7                 PDF & Document Viewer/Editor Software  2.299130e-230
# 138         Physical Access Control & Security Hardware   2.364925e-68
# 581               PDF & Document Viewer/Editor Software   1.566631e-20
# 14                PDF & Document Viewer/Editor Software  6.699300e-181
# 241               PDF & Document Viewer/Editor Software   1.172808e-43
#
#       median_group1  median_group2  diff
# 22             0.05           0.68  0.63
# 4              0.68           0.05  0.63
# 2              0.68           0.05  0.63
# 1124           0.06           0.68  0.62
# 158            0.06           0.68  0.62
# 159            0.06           0.68  0.62
# 29             0.68           0.07  0.61
# 61             0.08           0.68  0.60
# 34             0.08           0.68  0.60
# 169            0.68           0.08  0.60
# 7              0.08           0.68  0.60
# 138            0.68           0.08  0.60
# 581            0.09           0.68  0.59
# 14             0.09           0.68  0.59
# 241            0.09           0.68  0.59

# %%
# Rank product labels by central tendency for EPSS
epss_rank = df.groupby("product_label")["epss"].agg(["median", "mean", "count"]).sort_values("mean", ascending=False)
print("Top 15 product labels by EPSS:")
print(epss_rank.head(15))

# Rank product labels by central tendency for CVSS base score
cvss_rank = df.groupby("product_label")["baseScore"].agg(["median", "mean", "count"]).sort_values("median", ascending=False)
print("\nTop 15 product labels by CVSS base score:")
print(cvss_rank.head(15))
# Out:
# Top 15 product labels by EPSS:
#                                                 median      mean  count
# product_label
# Email & Messaging Server Software                0.210  6.488896    634
# FTP & Managed File Transfer Software             0.240  6.066998    563
# Web Server Software                              0.310  5.988652    282
# Application Server / Middleware                  0.220  4.925623   1083
# Web Scraping & Data Extraction Tools             0.120  4.674138    116
# Monitoring, Logging & Observability Software     0.200  4.664419   1600
# IT Asset & Endpoint Management Software          0.150  4.640862   1242
# Wiki & Knowledge Base Software                   0.260  4.351299    970
# DNS, Proxy & Network Privacy Tools               0.180  4.315473    201
# Video Surveillance & Security Camera Systems     0.190  3.753902    779
# Media Players & Streaming Client Software        0.190  3.636025    551
# Reverse Proxy & Load Balancer Software           0.225  3.545974    616
# Printers & Imaging Hardware                      0.155  3.535703    256
# IT Infrastructure & Server Management Software   0.210  3.417077   2316
# PDF & Document Viewer/Editor Software            0.680  3.331705   1132
#
# Top 15 product labels by CVSS base score:
#                                                     median      mean  count
# product_label
# Power, Energy & Electrical Equipment                   8.1  7.714286    469
# Manufacturing Execution Systems & Engineering S...     7.8  7.403254   1045
# PDF & Document Viewer/Editor Software                  7.8  6.651060   1132
# Image, Photo & Video Editing Software                  7.8  6.973397   2184
# Networking Hardware (Routers, Switches, Access ...     7.7  7.515353   4820
# Industrial Control Systems & PLCs                      7.6  7.416282   2125
# Physical Access Control & Security Hardware            7.5  7.333333    354
# Industrial Automation Hardware & Equipment             7.5  7.457479    849
# Building Management & Automation Systems               7.5  7.372461    512
# Productivity & Office Software                         7.5  6.908379   1277
# System-on-Chip, Processors & Semiconductor Comp...     7.5  6.748599   2426
# Web Browsers & Extensions                              7.5  6.723911   2020
# Video Surveillance & Security Camera Systems           7.5  7.284852    779
# DNS, Proxy & Network Privacy Tools                     7.5  6.621891    201
# Integrated Development Environments (IDEs) & Co...     7.4  6.872247    663

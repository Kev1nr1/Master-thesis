# %% [markdown]
# # LDA Topic Analysis

# %%
import pandas as pd
import ast

df = pd.read_csv('datasets/labeled_vulnerabilities_IoT.csv')
df['description_cleaned'] = df['description_cleaned'].apply(ast.literal_eval)
df = df[df["product_label"] != "Other category"].copy()
df
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_29312\59611547.py:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('datasets/labeled_vulnerabilities_IoT.csv')
#                       id                                        description  \
# 12       EUVD-2026-24086  FreePBX api module version 17.0.8 and prior co...
# 18      EUVD-2025-209543  HTML injection vulnerability in PHP Point of S...
# 32       EUVD-2026-24084  This vulnerability exists in Quantum Networks ...
# 33       EUVD-2026-24083  This vulnerability exists in Quantum Networks ...
# 34       EUVD-2026-24079  This vulnerability exists in Quantum Networks ...
# ...                  ...                                                ...
# 129054   EUVD-2024-48229  A vulnerability has been found in SourceCodest...
# 129056   EUVD-2024-48247  A vulnerability, which was classified as criti...
# 129057   EUVD-2024-48230  A vulnerability was found in SourceCodester Es...
# 129060   EUVD-2024-36450  Dell Peripheral Manager, versions prior to 1.7...
# 129064   EUVD-2024-48260  A vulnerability classified as critical has bee...
#
#                     datePublished                dateUpdated  \
# 12       Apr 21, 2026, 3:32:19 PM   Apr 21, 2026, 3:32:19 PM
# 18       Apr 21, 2026, 3:15:31 PM   Apr 21, 2026, 3:15:31 PM
# 32      Apr 21, 2026, 12:30:24 PM  Apr 21, 2026, 12:30:24 PM
# 33      Apr 21, 2026, 12:30:24 PM  Apr 21, 2026, 12:30:24 PM
# 34      Apr 21, 2026, 12:30:24 PM  Apr 21, 2026, 12:30:24 PM
# ...                           ...                        ...
# 129054   Jul 31, 2024, 3:31:04 AM   Jul 31, 2024, 2:16:13 PM
# 129056   Jul 31, 2024, 8:00:07 AM   Jul 31, 2024, 2:01:23 PM
# 129057   Jul 31, 2024, 4:00:08 AM   Jul 31, 2024, 2:01:06 PM
# 129060   Jul 31, 2024, 8:25:10 AM   Jul 31, 2024, 1:53:39 PM
# 129064  Jul 31, 2024, 11:00:08 AM   Jul 31, 2024, 1:05:37 PM
#
#         baseScoreVersion exploitedSince  \
# 12                   4.0            NaN
# 18                   4.0            NaN
# 32                   4.0            NaN
# 33                   4.0            NaN
# 34                   4.0            NaN
# ...                  ...            ...
# 129054               4.0            NaN
# 129056               4.0            NaN
# 129057               4.0            NaN
# 129060               3.1            NaN
# 129064               4.0            NaN
#
#                                           baseScoreVector  epss   assigner  \
# 12      CVSS:4.0/AV:N/AC:L/AT:N/PR:H/UI:N/VC:H/VI:H/VA...  0.00  VulnCheck
# 18      CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:A/VC:N/VI:N/VA...  0.00     INCIBE
# 32      CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:H/VI:N/VA...  0.05    CERT-In
# 33      CVSS:4.0/AV:A/AC:H/AT:N/PR:N/UI:N/VC:H/VI:H/VA...  0.02    CERT-In
# 34      CVSS:4.0/AV:A/AC:L/AT:N/PR:N/UI:N/VC:H/VI:H/VA...  0.02    CERT-In
# ...                                                   ...   ...        ...
# 129054  CVSS:4.0/AV:N/AC:L/AT:N/PR:L/UI:N/VC:N/VI:L/VA...  0.13      VulDB
# 129056  CVSS:4.0/AV:N/AC:L/AT:N/PR:L/UI:N/VC:L/VI:L/VA...  0.06      VulDB
# 129057  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...  0.10      VulDB
# 129060       CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H  0.10       dell
# 129064  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...  0.25      VulDB
#
#                                       aliases  \
# 12      CVE-2026-40520\nGHSA-h2vx-h73q-6q6w\n
# 18                           CVE-2025-41011\n
# 32      GHSA-v758-4p42-wqcm\nCVE-2026-41039\n
# 33      CVE-2026-41038\nGHSA-mqx2-c63m-7p93\n
# 34      GHSA-whhc-f8fh-m5cr\nCVE-2026-41037\n
# ...                                       ...
# 129054   GHSA-h78c-qhqh-fvgw\nCVE-2024-7285\n
# 129056   CVE-2024-7306\nGHSA-7xrv-5wwq-6q83\n
# 129057   GHSA-gwqx-f65w-5x4f\nCVE-2024-7286\n
# 129060  CVE-2024-37127\nGHSA-xqvw-7hh9-jm8v\n
# 129064   GHSA-w2gr-9pwc-5pm2\nCVE-2024-7320\n
#
#                                             enisaIdVendor  \
# 12      [{'id': '5b1962f2-dc98-3469-a8a9-2607d7ad2a7e'...
# 18      [{'id': 'febbc6a8-2662-3840-91ce-454ad0a93ac3'...
# 32      [{'id': '16a97add-c8a2-32a3-82f8-f889e1b43eff'...
# 33      [{'id': '01612813-85af-3a6d-ab0f-bfef2b5dd799'...
# 34      [{'id': '027c7f4c-420e-348a-8381-50de5859b1bc'...
# ...                                                   ...
# 129054  [{'id': 'fef8a8e2-f8a2-3a8b-be67-b095ab62a514'...
# 129056  [{'id': 'a5a2ff65-fe37-39ee-8434-53c3b69c4b61'...
# 129057  [{'id': '1b71b65b-abb8-344f-9e8c-89331dcbee57'...
# 129060  [{'id': '30cd5f39-c87b-358f-91f7-468c03678ac8'...
# 129064  [{'id': '290163b4-67c5-33a8-9f6e-eb813d7f879e'...
#
#                                                references  \
# 12      https://github.com/FreePBX/api/commit/5f194e39...
# 18      https://www.incibe.es/en/incibe-cert/notices/a...
# 32      https://www.cert-in.org.in/s2cMainServlet?page...
# 33      https://www.cert-in.org.in/s2cMainServlet?page...
# 34      https://www.cert-in.org.in/s2cMainServlet?page...
# ...                                                   ...
# 129054  https://vuldb.com/?id.273154\nhttps://vuldb.co...
# 129056  https://vuldb.com/?id.273198\nhttps://vuldb.co...
# 129057  https://vuldb.com/?id.273155\nhttps://vuldb.co...
# 129060  https://www.dell.com/support/kbdoc/en-us/00022...
# 129064  https://vuldb.com/?id.273231\nhttps://vuldb.co...
#
#                                            enisaIdProduct  baseScore  \
# 12      [{'id': '626fc52c-306c-3f6b-bd57-44bac375343b'...        8.6
# 18      [{'id': 'e74c211f-7496-3146-b1b6-4369eef8ddc7'...        5.1
# 32      [{'id': 'e2cf620c-c363-3933-8f4c-2b44c4b80619'...        8.7
# 33      [{'id': 'bef55d34-68ec-3135-8926-e6a5cbe01a6c'...        7.6
# 34      [{'id': '4462c671-891d-374f-b7c8-47b95df8de92'...        8.7
# ...                                                   ...        ...
# 129054  [{'id': '98bf0f60-a57b-3c30-aeb2-403c253081d5'...        5.3
# 129056  [{'id': '2dd8bd19-e292-308a-aa47-df02e695ad5a'...        5.3
# 129057  [{'id': '6a2919eb-8233-396b-a655-35f7ccb0ea4a'...        6.9
# 129060  [{'id': '7c62f44e-50d1-3074-a5dd-373708eade30'...        7.8
# 129064  [{'id': '48228bfe-9c8e-313e-8ade-203448cbb398'...        6.9
#
#                                    enisaUuid  \
# 12      0347c869-0ff0-3442-859c-409215d1fc0d
# 18      f1de0d28-be6c-3761-aa26-9bf0591de4e4
# 32      c97c6fc8-029c-3d61-ba2b-147e0b7030e0
# 33      b4e123e3-e421-32f6-987a-e13511207a86
# 34      e0e4574d-68db-33e3-b284-9eef816dcdd7
# ...                                      ...
# 129054  3c1b8524-3108-3ce2-9303-8a7a6e2240e4
# 129056  1ad5fd94-4ff1-3d01-8700-3dd6234ee573
# 129057  83ea8aa9-0e61-30c6-9c3a-8317b320f10c
# 129060  f8927bdc-f7c7-3b9a-bc2b-c1dfd1745b43
# 129064  954603d9-6741-357c-93a6-40c28ff13d29
#
#                                       description_cleaned  \
# 12      [freepbx, api, module, version, 1708, prior, c...
# 18      [html, injection, vulnerability, php, point, s...
# 32      [vulnerability, exists, quantum, network, rout...
# 33      [vulnerability, exists, quantum, network, rout...
# 34      [vulnerability, exists, quantum, network, rout...
# ...                                                   ...
# 129054  [vulnerability, ha, found, sourcecodester, est...
# 129056  [vulnerability, wa, classified, critical, wa, ...
# 129057  [vulnerability, wa, found, sourcecodester, est...
# 129060  [dell, peripheral, manager, version, prior, 17...
# 129064  [vulnerability, classified, critical, ha, foun...
#
#                                    product_name        vendor_name  \
# 12                                          API            FreePBX
# 18                            PHP Point of Sale  PHP Point Of Sale
# 32                              Router QN-I-470   Quantum Networks
# 33                              Router QN-I-470   Quantum Networks
# 34                              Router QN-I-470   Quantum Networks
# ...                                         ...                ...
# 129054  Establishment Billing Management System     SourceCodester
# 129056  Establishment Billing Management System     SourceCodester
# 129057  Establishment Billing Management System     SourceCodester
# 129060                  Dell Peripheral Manager               Dell
# 129064      Online Blood Bank Management System       itsourcecode
#
#                                             product_label
# 12      Telecommunications peripheral equipment, switc...
# 18      Payment and ticketing machines (i.e. self-serv...
# 32      Telecommunications peripheral equipment, switc...
# 33      Telecommunications peripheral equipment, switc...
# 34      Telecommunications peripheral equipment, switc...
# ...                                                   ...
# 129054  Payment and ticketing machines (i.e. self-serv...
# 129056  Payment and ticketing machines (i.e. self-serv...
# 129057  Payment and ticketing machines (i.e. self-serv...
# 129060   Input/output devices (keyboard, mouse, monitors)
# 129064                                  Medical equipment
#
# [33692 rows x 19 columns]

# %% [markdown]
# ## Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary
import numpy as np
import itertools

tokenized_docs = df["description_cleaned"].tolist()
texts = [" ".join(doc) for doc in tokenized_docs]

count_vectorizer = CountVectorizer(
    max_df=0.5,
    min_df=10,
    max_features=50000,
    ngram_range=(1, 2),
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
    stop_words='english',
)
dtm_counts = count_vectorizer.fit_transform(texts)
count_features = count_vectorizer.get_feature_names_out()

print(f"Vocabulary size: {len(count_features)}")
print(f"Document-term matrix shape: {dtm_counts.shape}")

gensim_dict = Dictionary(tokenized_docs)
# Out:
# Vocabulary size: 15001
# Document-term matrix shape: (33692, 15001)

# %%
def get_top_words_per_topic(model, feature_names, n_words=10):
    topics = []
    for topic in model.components_:
        top_indices = topic.argsort()[:-n_words - 1:-1]
        topics.append([feature_names[i] for i in top_indices])
    return topics


def topic_diversity(topics):
    all_words = [w for topic in topics for w in topic]
    if not all_words:
        return 0.0
    return len(set(all_words)) / len(all_words)


def coherence_score(topics, tokenized_docs, dictionary):
    cm = CoherenceModel(
        topics=topics,
        texts=tokenized_docs,
        dictionary=dictionary,
        coherence='c_v',
    )
    return cm.get_coherence()

# %% [markdown]
# ## Grid search hyperparameters

# %%
k_range = [10, 15, 20, 25, 30, 35, 40]
alpha_range = [0.05, 0.1, 0.3]
beta_range = [None, 0.01, 0.1]  # None = sklearn auto

lda_results = []

for k, alpha, beta in itertools.product(k_range, alpha_range, beta_range):
    lda = LatentDirichletAllocation(
        n_components=k,
        doc_topic_prior=alpha,
        topic_word_prior=beta,
        max_iter=20,
        learning_method='batch',
        random_state=1,
    )
    lda.fit(dtm_counts)

    topics = get_top_words_per_topic(lda, count_features, n_words=10)
    coherence = coherence_score(topics, tokenized_docs, gensim_dict)
    diversity = topic_diversity(topics)

    lda_results.append({
        'k': k,
        'alpha': alpha,
        'beta': beta,
        'coherence': coherence,
        'diversity': diversity,
        'combined_score': coherence * diversity, #to get a score between 0 and 1, with both contributing equally
    })
    print(f"k={k:>2} alpha={alpha} beta={beta}: "
          f"coherence={coherence:.4f} diversity={diversity:.3f}")

lda_results_df = pd.DataFrame(lda_results).sort_values('combined_score', ascending=False)
# Out:
# k=10 alpha=0.05 beta=None: coherence=0.7066 diversity=0.770
# k=10 alpha=0.05 beta=0.01: coherence=0.7090 diversity=0.770
# k=10 alpha=0.05 beta=0.1: coherence=0.7066 diversity=0.770
# k=10 alpha=0.1 beta=None: coherence=0.7054 diversity=0.770
# k=10 alpha=0.1 beta=0.01: coherence=0.7054 diversity=0.770
# k=10 alpha=0.1 beta=0.1: coherence=0.7054 diversity=0.770
# k=10 alpha=0.3 beta=None: coherence=0.6885 diversity=0.770
# k=10 alpha=0.3 beta=0.01: coherence=0.6893 diversity=0.770
# k=10 alpha=0.3 beta=0.1: coherence=0.6885 diversity=0.770
# k=15 alpha=0.05 beta=None: coherence=0.6665 diversity=0.700
# k=15 alpha=0.05 beta=0.01: coherence=0.6666 diversity=0.707
# k=15 alpha=0.05 beta=0.1: coherence=0.6665 diversity=0.700
# k=15 alpha=0.1 beta=None: coherence=0.6721 diversity=0.727
# k=15 alpha=0.1 beta=0.01: coherence=0.6717 diversity=0.733
# k=15 alpha=0.1 beta=0.1: coherence=0.6717 diversity=0.720
# k=15 alpha=0.3 beta=None: coherence=0.6795 diversity=0.747
# k=15 alpha=0.3 beta=0.01: coherence=0.6795 diversity=0.747
# k=15 alpha=0.3 beta=0.1: coherence=0.6795 diversity=0.747
# k=20 alpha=0.05 beta=None: coherence=0.6912 diversity=0.680
# k=20 alpha=0.05 beta=0.01: coherence=0.6863 diversity=0.680
# k=20 alpha=0.05 beta=0.1: coherence=0.6901 diversity=0.690
# k=20 alpha=0.1 beta=None: coherence=0.6987 diversity=0.685
# k=20 alpha=0.1 beta=0.01: coherence=0.6939 diversity=0.685
# k=20 alpha=0.1 beta=0.1: coherence=0.6964 diversity=0.670
# k=20 alpha=0.3 beta=None: coherence=0.6944 diversity=0.665
# k=20 alpha=0.3 beta=0.01: coherence=0.6952 diversity=0.670
# k=20 alpha=0.3 beta=0.1: coherence=0.6968 diversity=0.670
# k=25 alpha=0.05 beta=None: coherence=0.6646 diversity=0.648
# k=25 alpha=0.05 beta=0.01: coherence=0.6706 diversity=0.656
# k=25 alpha=0.05 beta=0.1: coherence=0.6721 diversity=0.656
# k=25 alpha=0.1 beta=None: coherence=0.6797 diversity=0.664
# k=25 alpha=0.1 beta=0.01: coherence=0.6788 diversity=0.672
# k=25 alpha=0.1 beta=0.1: coherence=0.6776 diversity=0.672
# k=25 alpha=0.3 beta=None: coherence=0.6985 diversity=0.700
# k=25 alpha=0.3 beta=0.01: coherence=0.6952 diversity=0.700
# k=25 alpha=0.3 beta=0.1: coherence=0.6962 diversity=0.696
# k=30 alpha=0.05 beta=None: coherence=0.6954 diversity=0.673
# k=30 alpha=0.05 beta=0.01: coherence=0.6864 diversity=0.670
# k=30 alpha=0.05 beta=0.1: coherence=0.6926 diversity=0.680
# k=30 alpha=0.1 beta=None: coherence=0.6876 diversity=0.673
# k=30 alpha=0.1 beta=0.01: coherence=0.6857 diversity=0.673
# k=30 alpha=0.1 beta=0.1: coherence=0.7018 diversity=0.667
# k=30 alpha=0.3 beta=None: coherence=0.6803 diversity=0.677
# k=30 alpha=0.3 beta=0.01: coherence=0.6839 diversity=0.680
# k=30 alpha=0.3 beta=0.1: coherence=0.6771 diversity=0.680
# k=35 alpha=0.05 beta=None: coherence=0.6950 diversity=0.617
# k=35 alpha=0.05 beta=0.01: coherence=0.6936 diversity=0.614
# k=35 alpha=0.05 beta=0.1: coherence=0.7010 diversity=0.614
# k=35 alpha=0.1 beta=None: coherence=0.6989 diversity=0.646
# k=35 alpha=0.1 beta=0.01: coherence=0.7016 diversity=0.651
# k=35 alpha=0.1 beta=0.1: coherence=0.7014 diversity=0.649
# k=35 alpha=0.3 beta=None: coherence=0.6939 diversity=0.669
# k=35 alpha=0.3 beta=0.01: coherence=0.7030 diversity=0.674
# k=35 alpha=0.3 beta=0.1: coherence=0.6905 diversity=0.666
# k=40 alpha=0.05 beta=None: coherence=0.6981 diversity=0.632
# k=40 alpha=0.05 beta=0.01: coherence=0.7070 diversity=0.637
# k=40 alpha=0.05 beta=0.1: coherence=0.7007 diversity=0.645
# k=40 alpha=0.1 beta=None: coherence=0.7212 diversity=0.647
# k=40 alpha=0.1 beta=0.01: coherence=0.7264 diversity=0.642
# k=40 alpha=0.1 beta=0.1: coherence=0.6906 diversity=0.642
# k=40 alpha=0.3 beta=None: coherence=0.7115 diversity=0.677
# k=40 alpha=0.3 beta=0.01: coherence=0.7101 diversity=0.685
# k=40 alpha=0.3 beta=0.1: coherence=0.6979 diversity=0.675

# %% [markdown]
# ## Showing best configuration

# %%
print("Top 10 configs (by coherence * diversity):")
print(lda_results_df.head(10).to_string(index=False))

best_config = lda_results_df.iloc[0]
print(f"\nBest config: k={int(best_config['k'])}, alpha={best_config['alpha']}, "
      f"beta={best_config['beta']} "
      f"-> coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}")
# Out:
# Top 10 configs (by coherence * diversity):
#  k  alpha  beta  coherence  diversity  combined_score
# 10   0.05  0.01   0.709037   0.770000        0.545959
# 10   0.05   NaN   0.706623   0.770000        0.544100
# 10   0.05  0.10   0.706623   0.770000        0.544100
# 10   0.10   NaN   0.705433   0.770000        0.543183
# 10   0.10  0.01   0.705433   0.770000        0.543183
# 10   0.10  0.10   0.705433   0.770000        0.543183
# 10   0.30  0.01   0.689285   0.770000        0.530749
# 10   0.30   NaN   0.688484   0.770000        0.530133
# 10   0.30  0.10   0.688484   0.770000        0.530133
# 15   0.30  0.01   0.679548   0.746667        0.507396
#
# Best config: k=10, alpha=0.05, beta=0.01 -> coherence=0.7090, diversity=0.770

# %%
def print_topics(model, feature_names, n_words=10):
    for i, topic in enumerate(model.components_):
        top_words = [feature_names[j] for j in topic.argsort()[:-n_words - 1:-1]]
        print(f"Topic {i:02d}: {', '.join(top_words)}")

lda_30_None = LatentDirichletAllocation(
    n_components=30,
    doc_topic_prior=0.3,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
lda_30_None.fit(dtm_counts)

print("=== k=30, alpha=0.3, beta=None ===")
print_topics(lda_30_None, count_features, n_words=10)
# Out:
# === k=30, alpha=0.3, beta=None ===
# Topic 00: kernel, path, memory, linux, following, traversal, fix, resolved, linux kernel, path traversal
# Topic 01: xss, scripting, crosssite scripting, crosssite, malicious, scripting xss, xss vulnerability, script, stored, javascript
# Topic 02: oracle, access, cvss, attack, impact, data, successful, successful attack, unauthorized, product
# Topic 03: ibm, session, xforce, ibm xforce, vulnerable, user, potentially leading, leading, potentially, allows
# Topic 04: earlier, user, version, file, version earlier, requires, exploitation, open, interaction, affected
# Topic 05: information, access, sensitive, attacker, sensitive information, data, disclosure, information disclosure, device, file
# Topic 06: crafted, specially, specially crafted, ibm, attacker, exists, vulnerability exists, request, trigger, http
# Topic 07: issue, macos, app, fixed, issue fixed, addressed, able, issue addressed, improved, addressed improved
# Topic 08: sql, issue, affect, issue affect, allows, element, upload, injection, improper, special
# Topic 09: page, access, user, inject arbitrary, inject, plugin, wordpress, web, insufficient, escaping
# Topic 10: plugin, including, wordpress, make, vulnerable, possible, version, version including, plugin wordpress, attacker
# Topic 11: version, prior, version prior, prior version, issue, server, version version, application, management, patch
# Topic 12: window, privilege, microsoft, elevation, elevation privilege, privilege vulnerability, server, service, xml, tibco
# Topic 13: attack, manipulation, file, exploit, remotely, lead, used, argument, public, manipulation argument
# Topic 14: php, file, java, allows, program, local, local file, issue, affect, control
# Topic 15: outofbounds, ruggedcom, read, version, outofbounds read, crash, attacker, scalance, application, pointer
# Topic 16: request, affect, issue, issue affect, forgery, request forgery, crosssite, allows, crosssite request, csrf
# Topic 17: service, denial, denial service, cause, condition, network, packet, attacker, device, series
# Topic 18: attacker, exploit, allow, interface, affected, exploit vulnerability, attacker exploit, cisco, device, allow attacker
# Topic 19: code, execute, attacker, file, malicious, remote, result, leverage, context, code context
# Topic 20: authorization, control, security, missing, access control, issue, access, allows, missing authorization, authorization vulnerability
# Topic 21: sql, parameter, query, database, attacker, injection, sql injection, tensorflow, user, sql query
# Topic 22: request, server, attacker, authentication, api, endpoint, user, version, key, client
# Topic 23: user, privilege, local, authenticated, attacker, password, allow, account, access, authenticated user
# Topic 24: server, mysql, mysql server, redirect, prior, allows, multiple, protocol, attacker, portal
# Topic 25: improper, input, web, page, generation, web page, scripting, crosssite scripting, neutralization, improper neutralization
# Topic 26: version, file, user, issue, fixed, using, application, patched, content, source
# Topic 27: code, execution, command, remote, arbitrary, code execution, attacker, remote code, execute, injection
# Topic 28: plugin, wordpress, doe, user, wordpress plugin, form, admin, plugin doe, escape, attack
# Topic 29: buffer, overflow, buffer overflow, user, upgrade, issue, known, apache, workarounds, known workarounds

# %%
lda_30_001 = LatentDirichletAllocation(
    n_components=30,
    doc_topic_prior=0.3,
    topic_word_prior=0.01,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
lda_30_001.fit(dtm_counts)

print("=== k=30, alpha=0.3, beta=0.01 ===")
print_topics(lda_30_001, count_features, n_words=10)
# Out:
# === k=30, alpha=0.3, beta=0.01 ===
# Topic 00: path, kernel, memory, linux, following, traversal, fix, resolved, linux kernel, path traversal
# Topic 01: xss, scripting, crosssite scripting, crosssite, malicious, scripting xss, xss vulnerability, script, stored, javascript
# Topic 02: oracle, access, cvss, attack, impact, data, successful, successful attack, unauthorized, base
# Topic 03: ibm, session, xforce, ibm xforce, vulnerable, user, potentially leading, potentially, leading, allows
# Topic 04: earlier, user, version, file, version earlier, requires, exploitation, open, interaction, affected
# Topic 05: information, access, sensitive, attacker, sensitive information, data, disclosure, information disclosure, device, file
# Topic 06: crafted, specially, specially crafted, attacker, ibm, exists, vulnerability exists, request, trigger, http
# Topic 07: issue, macos, app, fixed, issue fixed, addressed, able, issue addressed, improved, addressed improved
# Topic 08: issue, sql, affect, issue affect, allows, upload, element, injection, improper, special
# Topic 09: page, access, user, inject arbitrary, inject, plugin, wordpress, web, insufficient, vulnerable
# Topic 10: plugin, including, wordpress, make, possible, vulnerable, version, version including, plugin wordpress, attacker
# Topic 11: version, prior, version prior, prior version, issue, server, version version, application, management, patch
# Topic 12: window, privilege, microsoft, elevation, elevation privilege, server, privilege vulnerability, service, xml, tibco
# Topic 13: attack, manipulation, file, exploit, remotely, lead, used, argument, public, manipulation argument
# Topic 14: php, file, java, allows, program, local, local file, issue, affect, control
# Topic 15: outofbounds, read, ruggedcom, version, outofbounds read, crash, attacker, scalance, application, pointer
# Topic 16: request, affect, issue, issue affect, forgery, request forgery, crosssite, allows, crosssite request, csrf
# Topic 17: service, denial, denial service, cause, condition, network, packet, attacker, device, series
# Topic 18: attacker, exploit, allow, interface, affected, exploit vulnerability, attacker exploit, cisco, device, allow attacker
# Topic 19: code, execute, attacker, file, malicious, remote, result, leverage, context, code context
# Topic 20: authorization, control, security, missing, access control, issue, access, allows, missing authorization, authorization vulnerability
# Topic 21: sql, parameter, query, database, attacker, injection, sql injection, tensorflow, user, sql query
# Topic 22: request, server, attacker, authentication, api, endpoint, user, key, version, client
# Topic 23: user, privilege, local, authenticated, attacker, password, allow, account, access, authenticated user
# Topic 24: server, mysql, mysql server, redirect, prior, allows, multiple, protocol, portal, attacker
# Topic 25: improper, input, web, page, generation, web page, scripting, crosssite scripting, neutralization, improper neutralization
# Topic 26: version, file, user, issue, fixed, using, application, patched, content, used
# Topic 27: code, execution, command, remote, arbitrary, code execution, attacker, remote code, execute, injection
# Topic 28: plugin, wordpress, doe, user, wordpress plugin, form, admin, plugin doe, escape, attack
# Topic 29: buffer, overflow, buffer overflow, user, upgrade, issue, known, apache, workarounds, known workarounds

# %%
lda_10 = LatentDirichletAllocation(
    n_components=10,
    doc_topic_prior=0.05,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
lda_10.fit(dtm_counts)

print("=== k=10, alpha=0.05, beta=None ===")
print_topics(lda_10, count_features, n_words=10)
# Out:
# === k=10, alpha=0.05, beta=None ===
# Topic 00: file, privilege, path, lead, memory, user, service, needed, execution, local
# Topic 01: xss, version, scripting, crosssite, attacker, crosssite scripting, malicious, scripting xss, user, javascript
# Topic 02: oracle, access, cvss, impact, attack, successful, data, server, attacker, unauthorized
# Topic 03: attack, manipulation, file, exploit, remotely, lead, used, argument, public, manipulation argument
# Topic 04: version, user, command, privilege, earlier, attacker, arbitrary, file, allow, malicious
# Topic 05: attacker, version, access, allow, prior, device, exploit, version prior, affected, allows
# Topic 06: code, attacker, execute, remote, arbitrary, file, execution, code execution, ibm, arbitrary code
# Topic 07: issue, issue affect, affect, allows, crosssite, improper, page, neutralization, improper neutralization, web
# Topic 08: version, user, issue, file, server, prior, allows, attacker, request, sql
# Topic 09: plugin, wordpress, version, including, make, vulnerable, version including, attacker, plugin wordpress, possible

# %% [markdown]
# ## Fitting the model

# %%
final_model = LatentDirichletAllocation(
    n_components=10,
    doc_topic_prior=0.05,
    topic_word_prior=0.1,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
final_model.fit(dtm_counts)
# Out:
# LatentDirichletAllocation(doc_topic_prior=0.05, max_iter=20, random_state=1,
#                           topic_word_prior=0.1)

# %% [markdown]
# ## Analysis

# %%
doc_topic_dist = final_model.transform(dtm_counts)

# %%
import pandas as pd
from scipy.spatial.distance import jensenshannon

doc_topic_df = pd.DataFrame(doc_topic_dist)
doc_topic_df['category'] = df['product_label'] 

category_profiles = doc_topic_df.groupby('category').mean() 

n = len(category_profiles)
dist_matrix = np.zeros((n, n))
for i in range(n):
    for j in range(n):
        dist_matrix[i, j] = jensenshannon(category_profiles.iloc[i], category_profiles.iloc[j])

dist_df = pd.DataFrame(dist_matrix, index=category_profiles.index, columns=category_profiles.index)

# %%
dist_df
# Out:
# category                                            Alarm and fire detection systems  \
# category
# Alarm and fire detection systems                                            0.000000
# Audio equipment (players, speakers, headphones,...                          0.133058
# Batteries                                                                   0.370747
# Communication equipment / transmitting-receivin...                          0.151845
# Computers, laptops, servers                                                 0.113999
# Electrical devices for personal and recreationa...                          0.669248
# Electronic components                                                       0.203658
# Energy storage systems                                                      0.205693
# Gas appliances                                                              0.477881
# Household appliances                                                        0.564144
# Input/output devices (keyboard, mouse, monitors)                            0.131629
# Machinery                                                                   0.202211
# Measuring and weighing equipment (MID)                                      0.232785
# Measuring equipment (non-MID)                                               0.223446
# Medical equipment                                                           0.138041
# Payment and ticketing machines (i.e. self-servi...                          0.147179
# Power electronics                                                           0.367232
# Printers, copiers, scanners                                                 0.114043
# Recreational vehicles                                                       0.462231
# Smart devices / home automation                                             0.153713
# Switches, plugs, sockets, connectors, switchgear                            0.455944
# Telecommunications peripheral equipment, switch...                          0.094505
# Telephones, smartphones, e-readers, wearables                               0.166518
# Televisions, monitors, projectors, LED screens ...                          0.216444
# Toys                                                                        0.313491
# Transformers, power supplies, chargers                                      0.741135
# Vehicles                                                                    0.425436
#
# category                                            Audio equipment (players, speakers, headphones, microphones)  \
# category
# Alarm and fire detection systems                                                             0.133058
# Audio equipment (players, speakers, headphones,...                                           0.000000
# Batteries                                                                                    0.380573
# Communication equipment / transmitting-receivin...                                           0.138582
# Computers, laptops, servers                                                                  0.089571
# Electrical devices for personal and recreationa...                                           0.667553
# Electronic components                                                                        0.155346
# Energy storage systems                                                                       0.205460
# Gas appliances                                                                               0.462655
# Household appliances                                                                         0.497851
# Input/output devices (keyboard, mouse, monitors)                                             0.145672
# Machinery                                                                                    0.194539
# Measuring and weighing equipment (MID)                                                       0.178476
# Measuring equipment (non-MID)                                                                0.156373
# Medical equipment                                                                            0.106855
# Payment and ticketing machines (i.e. self-servi...                                           0.081724
# Power electronics                                                                            0.384868
# Printers, copiers, scanners                                                                  0.128979
# Recreational vehicles                                                                        0.465706
# Smart devices / home automation                                                              0.140122
# Switches, plugs, sockets, connectors, switchgear                                             0.443786
# Telecommunications peripheral equipment, switch...                                           0.109911
# Telephones, smartphones, e-readers, wearables                                                0.146841
# Televisions, monitors, projectors, LED screens ...                                           0.148252
# Toys                                                                                         0.263888
# Transformers, power supplies, chargers                                                       0.755862
# Vehicles                                                                                     0.417193
#
# category                                            Batteries  \
# category
# Alarm and fire detection systems                     0.370747
# Audio equipment (players, speakers, headphones,...   0.380573
# Batteries                                            0.000000
# Communication equipment / transmitting-receivin...   0.313615
# Computers, laptops, servers                          0.343619
# Electrical devices for personal and recreationa...   0.816006
# Electronic components                                0.312369
# Energy storage systems                               0.361021
# Gas appliances                                       0.359054
# Household appliances                                 0.516479
# Input/output devices (keyboard, mouse, monitors)     0.384819
# Machinery                                            0.371174
# Measuring and weighing equipment (MID)               0.286443
# Measuring equipment (non-MID)                        0.435862
# Medical equipment                                    0.409481
# Payment and ticketing machines (i.e. self-servi...   0.330931
# Power electronics                                    0.502644
# Printers, copiers, scanners                          0.397659
# Recreational vehicles                                0.349322
# Smart devices / home automation                      0.343750
# Switches, plugs, sockets, connectors, switchgear     0.517641
# Telecommunications peripheral equipment, switch...   0.354700
# Telephones, smartphones, e-readers, wearables        0.328848
# Televisions, monitors, projectors, LED screens ...   0.391180
# Toys                                                 0.416962
# Transformers, power supplies, chargers               0.791273
# Vehicles                                             0.342650
#
# category                                            Communication equipment / transmitting-receiving equipment  \
# category
# Alarm and fire detection systems                                                             0.151845
# Audio equipment (players, speakers, headphones,...                                           0.138582
# Batteries                                                                                    0.313615
# Communication equipment / transmitting-receivin...                                           0.000000
# Computers, laptops, servers                                                                  0.147013
# Electrical devices for personal and recreationa...                                           0.676393
# Electronic components                                                                        0.171481
# Energy storage systems                                                                       0.203957
# Gas appliances                                                                               0.450351
# Household appliances                                                                         0.527026
# Input/output devices (keyboard, mouse, monitors)                                             0.203174
# Machinery                                                                                    0.234345
# Measuring and weighing equipment (MID)                                                       0.193057
# Measuring equipment (non-MID)                                                                0.224615
# Medical equipment                                                                            0.168470
# Payment and ticketing machines (i.e. self-servi...                                           0.152728
# Power electronics                                                                            0.387717
# Printers, copiers, scanners                                                                  0.159062
# Recreational vehicles                                                                        0.448041
# Smart devices / home automation                                                              0.170845
# Switches, plugs, sockets, connectors, switchgear                                             0.507777
# Telecommunications peripheral equipment, switch...                                           0.130685
# Telephones, smartphones, e-readers, wearables                                                0.190960
# Televisions, monitors, projectors, LED screens ...                                           0.170549
# Toys                                                                                         0.285746
# Transformers, power supplies, chargers                                                       0.782000
# Vehicles                                                                                     0.377178
#
# category                                            Computers, laptops, servers  \
# category
# Alarm and fire detection systems                                       0.113999
# Audio equipment (players, speakers, headphones,...                     0.089571
# Batteries                                                              0.343619
# Communication equipment / transmitting-receivin...                     0.147013
# Computers, laptops, servers                                            0.000000
# Electrical devices for personal and recreationa...                     0.699791
# Electronic components                                                  0.120535
# Energy storage systems                                                 0.195764
# Gas appliances                                                         0.459688
# Household appliances                                                   0.490938
# Input/output devices (keyboard, mouse, monitors)                       0.087841
# Machinery                                                              0.186517
# Measuring and weighing equipment (MID)                                 0.157682
# Measuring equipment (non-MID)                                          0.196389
# Medical equipment                                                      0.142015
# Payment and ticketing machines (i.e. self-servi...                     0.055501
# Power electronics                                                      0.375357
# Printers, copiers, scanners                                            0.149834
# Recreational vehicles                                                  0.434341
# Smart devices / home automation                                        0.112121
# Switches, plugs, sockets, connectors, switchgear                       0.411300
# Telecommunications peripheral equipment, switch...                     0.099129
# Telephones, smartphones, e-readers, wearables                          0.085596
# Televisions, monitors, projectors, LED screens ...                     0.197897
# Toys                                                                   0.248563
# Transformers, power supplies, chargers                                 0.753227
# Vehicles                                                               0.420941
#
# category                                            Electrical devices for personal and recreational use  \
# category
# Alarm and fire detection systems                                                             0.669248
# Audio equipment (players, speakers, headphones,...                                           0.667553
# Batteries                                                                                    0.816006
# Communication equipment / transmitting-receivin...                                           0.676393
# Computers, laptops, servers                                                                  0.699791
# Electrical devices for personal and recreationa...                                           0.000000
# Electronic components                                                                        0.742576
# Energy storage systems                                                                       0.716278
# Gas appliances                                                                               0.816219
# Household appliances                                                                         0.820619
# Input/output devices (keyboard, mouse, monitors)                                             0.696453
# Machinery                                                                                    0.730439
# Measuring and weighing equipment (MID)                                                       0.735407
# Measuring equipment (non-MID)                                                                0.596004
# Medical equipment                                                                            0.672169
# Payment and ticketing machines (i.e. self-servi...                                           0.709870
# Power electronics                                                                            0.813055
# Printers, copiers, scanners                                                                  0.680683
# Recreational vehicles                                                                        0.819053
# Smart devices / home automation                                                              0.714920
# Switches, plugs, sockets, connectors, switchgear                                             0.810779
# Telecommunications peripheral equipment, switch...                                           0.677628
# Telephones, smartphones, e-readers, wearables                                                0.733352
# Televisions, monitors, projectors, LED screens ...                                           0.646226
# Toys                                                                                         0.735734
# Transformers, power supplies, chargers                                                       0.824827
# Vehicles                                                                                     0.817434
#
# category                                            Electronic components  \
# category
# Alarm and fire detection systems                                 0.203658
# Audio equipment (players, speakers, headphones,...               0.155346
# Batteries                                                        0.312369
# Communication equipment / transmitting-receivin...               0.171481
# Computers, laptops, servers                                      0.120535
# Electrical devices for personal and recreationa...               0.742576
# Electronic components                                            0.000000
# Energy storage systems                                           0.163533
# Gas appliances                                                   0.425509
# Household appliances                                             0.480453
# Input/output devices (keyboard, mouse, monitors)                 0.171839
# Machinery                                                        0.162415
# Measuring and weighing equipment (MID)                           0.141083
# Measuring equipment (non-MID)                                    0.235855
# Medical equipment                                                0.181355
# Payment and ticketing machines (i.e. self-servi...               0.116600
# Power electronics                                                0.366682
# Printers, copiers, scanners                                      0.189109
# Recreational vehicles                                            0.376931
# Smart devices / home automation                                  0.100504
# Switches, plugs, sockets, connectors, switchgear                 0.389861
# Telecommunications peripheral equipment, switch...               0.137650
# Telephones, smartphones, e-readers, wearables                    0.109354
# Televisions, monitors, projectors, LED screens ...               0.223825
# Toys                                                             0.247650
# Transformers, power supplies, chargers                           0.794874
# Vehicles                                                         0.366477
#
# category                                            Energy storage systems  \
# category
# Alarm and fire detection systems                                  0.205693
# Audio equipment (players, speakers, headphones,...                0.205460
# Batteries                                                         0.361021
# Communication equipment / transmitting-receivin...                0.203957
# Computers, laptops, servers                                       0.195764
# Electrical devices for personal and recreationa...                0.716278
# Electronic components                                             0.163533
# Energy storage systems                                            0.000000
# Gas appliances                                                    0.376577
# Household appliances                                              0.552070
# Input/output devices (keyboard, mouse, monitors)                  0.196737
# Machinery                                                         0.152658
# Measuring and weighing equipment (MID)                            0.210166
# Measuring equipment (non-MID)                                     0.245430
# Medical equipment                                                 0.147613
# Payment and ticketing machines (i.e. self-servi...                0.199439
# Power electronics                                                 0.405758
# Printers, copiers, scanners                                       0.169105
# Recreational vehicles                                             0.401777
# Smart devices / home automation                                   0.108358
# Switches, plugs, sockets, connectors, switchgear                  0.404003
# Telecommunications peripheral equipment, switch...                0.131706
# Telephones, smartphones, e-readers, wearables                     0.185674
# Televisions, monitors, projectors, LED screens ...                0.261488
# Toys                                                              0.372608
# Transformers, power supplies, chargers                            0.807266
# Vehicles                                                          0.304382
#
# category                                            Gas appliances  \
# category
# Alarm and fire detection systems                          0.477881
# Audio equipment (players, speakers, headphones,...        0.462655
# Batteries                                                 0.359054
# Communication equipment / transmitting-receivin...        0.450351
# Computers, laptops, servers                               0.459688
# Electrical devices for personal and recreationa...        0.816219
# Electronic components                                     0.425509
# Energy storage systems                                    0.376577
# Gas appliances                                            0.000000
# Household appliances                                      0.543367
# Input/output devices (keyboard, mouse, monitors)          0.467841
# Machinery                                                 0.413872
# Measuring and weighing equipment (MID)                    0.370311
# Measuring equipment (non-MID)                             0.462915
# Medical equipment                                         0.449686
# Payment and ticketing machines (i.e. self-servi...        0.431280
# Power electronics                                         0.633707
# Printers, copiers, scanners                               0.472985
# Recreational vehicles                                     0.401517
# Smart devices / home automation                           0.415917
# Switches, plugs, sockets, connectors, switchgear          0.482757
# Telecommunications peripheral equipment, switch...        0.441378
# Telephones, smartphones, e-readers, wearables             0.437402
# Televisions, monitors, projectors, LED screens ...        0.469447
# Toys                                                      0.588330
# Transformers, power supplies, chargers                    0.817423
# Vehicles                                                  0.247653
#
# category                                            Household appliances  ...  \
# category                                                                  ...
# Alarm and fire detection systems                                0.564144  ...
# Audio equipment (players, speakers, headphones,...              0.497851  ...
# Batteries                                                       0.516479  ...
# Communication equipment / transmitting-receivin...              0.527026  ...
# Computers, laptops, servers                                     0.490938  ...
# Electrical devices for personal and recreationa...              0.820619  ...
# Electronic components                                           0.480453  ...
# Energy storage systems                                          0.552070  ...
# Gas appliances                                                  0.543367  ...
# Household appliances                                            0.000000  ...
# Input/output devices (keyboard, mouse, monitors)                0.500067  ...
# Machinery                                                       0.573964  ...
# Measuring and weighing equipment (MID)                          0.409445  ...
# Measuring equipment (non-MID)                                   0.480001  ...
# Medical equipment                                               0.546216  ...
# Payment and ticketing machines (i.e. self-servi...              0.470362  ...
# Power electronics                                               0.657793  ...
# Printers, copiers, scanners                                     0.586008  ...
# Recreational vehicles                                           0.639711  ...
# Smart devices / home automation                                 0.535322  ...
# Switches, plugs, sockets, connectors, switchgear                0.550784  ...
# Telecommunications peripheral equipment, switch...              0.543959  ...
# Telephones, smartphones, e-readers, wearables                   0.479021  ...
# Televisions, monitors, projectors, LED screens ...              0.470560  ...
# Toys                                                            0.415923  ...
# Transformers, power supplies, chargers                          0.824305  ...
# Vehicles                                                        0.613108  ...
#
# category                                            Printers, copiers, scanners  \
# category
# Alarm and fire detection systems                                       0.114043
# Audio equipment (players, speakers, headphones,...                     0.128979
# Batteries                                                              0.397659
# Communication equipment / transmitting-receivin...                     0.159062
# Computers, laptops, servers                                            0.149834
# Electrical devices for personal and recreationa...                     0.680683
# Electronic components                                                  0.189109
# Energy storage systems                                                 0.169105
# Gas appliances                                                         0.472985
# Household appliances                                                   0.586008
# Input/output devices (keyboard, mouse, monitors)                       0.175821
# Machinery                                                              0.155033
# Measuring and weighing equipment (MID)                                 0.257403
# Measuring equipment (non-MID)                                          0.239946
# Medical equipment                                                      0.080815
# Payment and ticketing machines (i.e. self-servi...                     0.165468
# Power electronics                                                      0.325255
# Printers, copiers, scanners                                            0.000000
# Recreational vehicles                                                  0.452045
# Smart devices / home automation                                        0.125888
# Switches, plugs, sockets, connectors, switchgear                       0.453598
# Telecommunications peripheral equipment, switch...                     0.099002
# Telephones, smartphones, e-readers, wearables                          0.189045
# Televisions, monitors, projectors, LED screens ...                     0.228508
# Toys                                                                   0.334171
# Transformers, power supplies, chargers                                 0.751015
# Vehicles                                                               0.386418
#
# category                                            Recreational vehicles  \
# category
# Alarm and fire detection systems                                 0.462231
# Audio equipment (players, speakers, headphones,...               0.465706
# Batteries                                                        0.349322
# Communication equipment / transmitting-receivin...               0.448041
# Computers, laptops, servers                                      0.434341
# Electrical devices for personal and recreationa...               0.819053
# Electronic components                                            0.376931
# Energy storage systems                                           0.401777
# Gas appliances                                                   0.401517
# Household appliances                                             0.639711
# Input/output devices (keyboard, mouse, monitors)                 0.461347
# Machinery                                                        0.350799
# Measuring and weighing equipment (MID)                           0.425597
# Measuring equipment (non-MID)                                    0.497512
# Medical equipment                                                0.474722
# Payment and ticketing machines (i.e. self-servi...               0.430587
# Power electronics                                                0.515766
# Printers, copiers, scanners                                      0.452045
# Recreational vehicles                                            0.000000
# Smart devices / home automation                                  0.385290
# Switches, plugs, sockets, connectors, switchgear                 0.399508
# Telecommunications peripheral equipment, switch...               0.425614
# Telephones, smartphones, e-readers, wearables                    0.424401
# Televisions, monitors, projectors, LED screens ...               0.514307
# Toys                                                             0.516092
# Transformers, power supplies, chargers                           0.822643
# Vehicles                                                         0.397635
#
# category                                            Smart devices / home automation  \
# category
# Alarm and fire detection systems                                           0.153713
# Audio equipment (players, speakers, headphones,...                         0.140122
# Batteries                                                                  0.343750
# Communication equipment / transmitting-receivin...                         0.170845
# Computers, laptops, servers                                                0.112121
# Electrical devices for personal and recreationa...                         0.714920
# Electronic components                                                      0.100504
# Energy storage systems                                                     0.108358
# Gas appliances                                                             0.415917
# Household appliances                                                       0.535322
# Input/output devices (keyboard, mouse, monitors)                           0.133632
# Machinery                                                                  0.111191
# Measuring and weighing equipment (MID)                                     0.184131
# Measuring equipment (non-MID)                                              0.225264
# Medical equipment                                                          0.119089
# Payment and ticketing machines (i.e. self-servi...                         0.120675
# Power electronics                                                          0.369172
# Printers, copiers, scanners                                                0.125888
# Recreational vehicles                                                      0.385290
# Smart devices / home automation                                            0.000000
# Switches, plugs, sockets, connectors, switchgear                           0.381810
# Telecommunications peripheral equipment, switch...                         0.084243
# Telephones, smartphones, e-readers, wearables                              0.113962
# Televisions, monitors, projectors, LED screens ...                         0.242485
# Toys                                                                       0.315744
# Transformers, power supplies, chargers                                     0.775762
# Vehicles                                                                   0.355132
#
# category                                            Switches, plugs, sockets, connectors, switchgear  \
# category
# Alarm and fire detection systems                                                            0.455944
# Audio equipment (players, speakers, headphones,...                                          0.443786
# Batteries                                                                                   0.517641
# Communication equipment / transmitting-receivin...                                          0.507777
# Computers, laptops, servers                                                                 0.411300
# Electrical devices for personal and recreationa...                                          0.810779
# Electronic components                                                                       0.389861
# Energy storage systems                                                                      0.404003
# Gas appliances                                                                              0.482757
# Household appliances                                                                        0.550784
# Input/output devices (keyboard, mouse, monitors)                                            0.385894
# Machinery                                                                                   0.340671
# Measuring and weighing equipment (MID)                                                      0.422275
# Measuring equipment (non-MID)                                                               0.437282
# Medical equipment                                                                           0.443634
# Payment and ticketing machines (i.e. self-servi...                                          0.415105
# Power electronics                                                                           0.503398
# Printers, copiers, scanners                                                                 0.453598
# Recreational vehicles                                                                       0.399508
# Smart devices / home automation                                                             0.381810
# Switches, plugs, sockets, connectors, switchgear                                            0.000000
# Telecommunications peripheral equipment, switch...                                          0.423728
# Telephones, smartphones, e-readers, wearables                                               0.399219
# Televisions, monitors, projectors, LED screens ...                                          0.517928
# Toys                                                                                        0.503723
# Transformers, power supplies, chargers                                                      0.812159
# Vehicles                                                                                    0.545204
#
# category                                            Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  \
# category
# Alarm and fire detection systems                                                             0.094505
# Audio equipment (players, speakers, headphones,...                                           0.109911
# Batteries                                                                                    0.354700
# Communication equipment / transmitting-receivin...                                           0.130685
# Computers, laptops, servers                                                                  0.099129
# Electrical devices for personal and recreationa...                                           0.677628
# Electronic components                                                                        0.137650
# Energy storage systems                                                                       0.131706
# Gas appliances                                                                               0.441378
# Household appliances                                                                         0.543959
# Input/output devices (keyboard, mouse, monitors)                                             0.130316
# Machinery                                                                                    0.147514
# Measuring and weighing equipment (MID)                                                       0.187461
# Measuring equipment (non-MID)                                                                0.186397
# Medical equipment                                                                            0.099667
# Payment and ticketing machines (i.e. self-servi...                                           0.122131
# Power electronics                                                                            0.372948
# Printers, copiers, scanners                                                                  0.099002
# Recreational vehicles                                                                        0.425614
# Smart devices / home automation                                                              0.084243
# Switches, plugs, sockets, connectors, switchgear                                             0.423728
# Telecommunications peripheral equipment, switch...                                           0.000000
# Telephones, smartphones, e-readers, wearables                                                0.134137
# Televisions, monitors, projectors, LED screens ...                                           0.190405
# Toys                                                                                         0.300952
# Transformers, power supplies, chargers                                                       0.780590
# Vehicles                                                                                     0.381861
#
# category                                            Telephones, smartphones, e-readers, wearables  \
# category
# Alarm and fire detection systems                                                         0.166518
# Audio equipment (players, speakers, headphones,...                                       0.146841
# Batteries                                                                                0.328848
# Communication equipment / transmitting-receivin...                                       0.190960
# Computers, laptops, servers                                                              0.085596
# Electrical devices for personal and recreationa...                                       0.733352
# Electronic components                                                                    0.109354
# Energy storage systems                                                                   0.185674
# Gas appliances                                                                           0.437402
# Household appliances                                                                     0.479021
# Input/output devices (keyboard, mouse, monitors)                                         0.115090
# Machinery                                                                                0.198198
# Measuring and weighing equipment (MID)                                                   0.141080
# Measuring equipment (non-MID)                                                            0.235347
# Medical equipment                                                                        0.169624
# Payment and ticketing machines (i.e. self-servi...                                       0.086520
# Power electronics                                                                        0.393983
# Printers, copiers, scanners                                                              0.189045
# Recreational vehicles                                                                    0.424401
# Smart devices / home automation                                                          0.113962
# Switches, plugs, sockets, connectors, switchgear                                         0.399219
# Telecommunications peripheral equipment, switch...                                       0.134137
# Telephones, smartphones, e-readers, wearables                                            0.000000
# Televisions, monitors, projectors, LED screens ...                                       0.230473
# Toys                                                                                     0.260345
# Transformers, power supplies, chargers                                                   0.754458
# Vehicles                                                                                 0.395459
#
# category                                            Televisions, monitors, projectors, LED screens and information kiosks  \
# category
# Alarm and fire detection systems                                                             0.216444
# Audio equipment (players, speakers, headphones,...                                           0.148252
# Batteries                                                                                    0.391180
# Communication equipment / transmitting-receivin...                                           0.170549
# Computers, laptops, servers                                                                  0.197897
# Electrical devices for personal and recreationa...                                           0.646226
# Electronic components                                                                        0.223825
# Energy storage systems                                                                       0.261488
# Gas appliances                                                                               0.469447
# Household appliances                                                                         0.470560
# Input/output devices (keyboard, mouse, monitors)                                             0.251419
# Machinery                                                                                    0.287157
# Measuring and weighing equipment (MID)                                                       0.188479
# Measuring equipment (non-MID)                                                                0.155664
# Medical equipment                                                                            0.203411
# Payment and ticketing machines (i.e. self-servi...                                           0.185639
# Power electronics                                                                            0.447131
# Printers, copiers, scanners                                                                  0.228508
# Recreational vehicles                                                                        0.514307
# Smart devices / home automation                                                              0.242485
# Switches, plugs, sockets, connectors, switchgear                                             0.517928
# Telecommunications peripheral equipment, switch...                                           0.190405
# Telephones, smartphones, e-readers, wearables                                                0.230473
# Televisions, monitors, projectors, LED screens ...                                           0.000000
# Toys                                                                                         0.253513
# Transformers, power supplies, chargers                                                       0.800890
# Vehicles                                                                                     0.429155
#
# category                                                Toys  \
# category
# Alarm and fire detection systems                    0.313491
# Audio equipment (players, speakers, headphones,...  0.263888
# Batteries                                           0.416962
# Communication equipment / transmitting-receivin...  0.285746
# Computers, laptops, servers                         0.248563
# Electrical devices for personal and recreationa...  0.735734
# Electronic components                               0.247650
# Energy storage systems                              0.372608
# Gas appliances                                      0.588330
# Household appliances                                0.415923
# Input/output devices (keyboard, mouse, monitors)    0.300057
# Machinery                                           0.358649
# Measuring and weighing equipment (MID)              0.267067
# Measuring equipment (non-MID)                       0.315697
# Medical equipment                                   0.334668
# Payment and ticketing machines (i.e. self-servi...  0.252984
# Power electronics                                   0.402138
# Printers, copiers, scanners                         0.334171
# Recreational vehicles                               0.516092
# Smart devices / home automation                     0.315744
# Switches, plugs, sockets, connectors, switchgear    0.503723
# Telecommunications peripheral equipment, switch...  0.300952
# Telephones, smartphones, e-readers, wearables       0.260345
# Televisions, monitors, projectors, LED screens ...  0.253513
# Toys                                                0.000000
# Transformers, power supplies, chargers              0.793692
# Vehicles                                            0.538642
#
# category                                            Transformers, power supplies, chargers  \
# category
# Alarm and fire detection systems                                                  0.741135
# Audio equipment (players, speakers, headphones,...                                0.755862
# Batteries                                                                         0.791273
# Communication equipment / transmitting-receivin...                                0.782000
# Computers, laptops, servers                                                       0.753227
# Electrical devices for personal and recreationa...                                0.824827
# Electronic components                                                             0.794874
# Energy storage systems                                                            0.807266
# Gas appliances                                                                    0.817423
# Household appliances                                                              0.824305
# Input/output devices (keyboard, mouse, monitors)                                  0.747566
# Machinery                                                                         0.786047
# Measuring and weighing equipment (MID)                                            0.794805
# Measuring equipment (non-MID)                                                     0.807335
# Medical equipment                                                                 0.760557
# Payment and ticketing machines (i.e. self-servi...                                0.749137
# Power electronics                                                                 0.757099
# Printers, copiers, scanners                                                       0.751015
# Recreational vehicles                                                             0.822643
# Smart devices / home automation                                                   0.775762
# Switches, plugs, sockets, connectors, switchgear                                  0.812159
# Telecommunications peripheral equipment, switch...                                0.780590
# Telephones, smartphones, e-readers, wearables                                     0.754458
# Televisions, monitors, projectors, LED screens ...                                0.800890
# Toys                                                                              0.793692
# Transformers, power supplies, chargers                                            0.000000
# Vehicles                                                                          0.811814
#
# category                                            Vehicles
# category
# Alarm and fire detection systems                    0.425436
# Audio equipment (players, speakers, headphones,...  0.417193
# Batteries                                           0.342650
# Communication equipment / transmitting-receivin...  0.377178
# Computers, laptops, servers                         0.420941
# Electrical devices for personal and recreationa...  0.817434
# Electronic components                               0.366477
# Energy storage systems                              0.304382
# Gas appliances                                      0.247653
# Household appliances                                0.613108
# Input/output devices (keyboard, mouse, monitors)    0.443245
# Machinery                                           0.359200
# Measuring and weighing equipment (MID)              0.367367
# Measuring equipment (non-MID)                       0.464717
# Medical equipment                                   0.380526
# Payment and ticketing machines (i.e. self-servi...  0.398610
# Power electronics                                   0.521422
# Printers, copiers, scanners                         0.386418
# Recreational vehicles                               0.397635
# Smart devices / home automation                     0.355132
# Switches, plugs, sockets, connectors, switchgear    0.545204
# Telecommunications peripheral equipment, switch...  0.381861
# Telephones, smartphones, e-readers, wearables       0.395459
# Televisions, monitors, projectors, LED screens ...  0.429155
# Toys                                                0.538642
# Transformers, power supplies, chargers              0.811814
# Vehicles                                            0.000000
#
# [27 rows x 27 columns]

# %%
# Get upper triangle indices (excludes diagonal/self and duplicate mirror pairs)
n = len(dist_df)
iu = np.triu_indices(n, k=1)  # k=1 skips the diagonal

pairs = pd.DataFrame({
    'category_a': dist_df.index[iu[0]],
    'category_b': dist_df.columns[iu[1]],
    'distance': dist_df.values[iu]
})

# Most distinct pairs (highest distance)
most_distinct = pairs.sort_values('distance', ascending=False).head(20)
print("=== Most distinct category pairs ===")
print(most_distinct.to_string(index=False))

# Most similar pairs (lowest distance, excluding identical category accidentally appearing twice if any)
most_similar = pairs.sort_values('distance', ascending=True).head(20)
print("\n=== Most similar category pairs ===")
print(most_similar.to_string(index=False))
# Out:
# === Most distinct category pairs ===
#                                                            category_a                                           category_b  distance
#                  Electrical devices for personal and recreational use               Transformers, power supplies, chargers  0.824827
#                                                  Household appliances               Transformers, power supplies, chargers  0.824305
#                                                 Recreational vehicles               Transformers, power supplies, chargers  0.822643
#                  Electrical devices for personal and recreational use                                 Household appliances  0.820619
#                  Electrical devices for personal and recreational use                                Recreational vehicles  0.819053
#                  Electrical devices for personal and recreational use                                             Vehicles  0.817434
#                                                        Gas appliances               Transformers, power supplies, chargers  0.817423
#                  Electrical devices for personal and recreational use                                       Gas appliances  0.816219
#                                                             Batteries Electrical devices for personal and recreational use  0.816006
#                  Electrical devices for personal and recreational use                                    Power electronics  0.813055
#                      Switches, plugs, sockets, connectors, switchgear               Transformers, power supplies, chargers  0.812159
#                                Transformers, power supplies, chargers                                             Vehicles  0.811814
#                  Electrical devices for personal and recreational use     Switches, plugs, sockets, connectors, switchgear  0.810779
#                                         Measuring equipment (non-MID)               Transformers, power supplies, chargers  0.807335
#                                                Energy storage systems               Transformers, power supplies, chargers  0.807266
# Televisions, monitors, projectors, LED screens and information kiosks               Transformers, power supplies, chargers  0.800890
#                                                 Electronic components               Transformers, power supplies, chargers  0.794874
#                                Measuring and weighing equipment (MID)               Transformers, power supplies, chargers  0.794805
#                                                                  Toys               Transformers, power supplies, chargers  0.793692
#                                                             Batteries               Transformers, power supplies, chargers  0.791273
#
# === Most similar category pairs ===
#                                                          category_a                                                                                                                                             category_b  distance
#                                         Computers, laptops, servers                                                                                    Payment and ticketing machines (i.e. self-service terminals – SSTs)  0.055501
#                                                   Medical equipment                                                                                                                            Printers, copiers, scanners  0.080815
#        Audio equipment (players, speakers, headphones, microphones)                                                                                    Payment and ticketing machines (i.e. self-service terminals – SSTs)  0.081724
#                                     Smart devices / home automation Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.084243
#                                         Computers, laptops, servers                                                                                                          Telephones, smartphones, e-readers, wearables  0.085596
# Payment and ticketing machines (i.e. self-service terminals – SSTs)                                                                                                          Telephones, smartphones, e-readers, wearables  0.086520
#                                         Computers, laptops, servers                                                                                                       Input/output devices (keyboard, mouse, monitors)  0.087841
#        Audio equipment (players, speakers, headphones, microphones)                                                                                                                            Computers, laptops, servers  0.089571
#                                    Alarm and fire detection systems Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.094505
#                                         Printers, copiers, scanners Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.099002
#                                         Computers, laptops, servers Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.099129
#                                                   Medical equipment Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.099667
#                                               Electronic components                                                                                                                        Smart devices / home automation  0.100504
#        Audio equipment (players, speakers, headphones, microphones)                                                                                                                                      Medical equipment  0.106855
#                                              Energy storage systems                                                                                                                        Smart devices / home automation  0.108358
#                                               Electronic components                                                                                                          Telephones, smartphones, e-readers, wearables  0.109354
#        Audio equipment (players, speakers, headphones, microphones) Telecommunications peripheral equipment, switches, routers, wireless access points, media converters, modems, network firewalls and security equipment  0.109911
#                                                           Machinery                                                                                                                        Smart devices / home automation  0.111191
#                                         Computers, laptops, servers                                                                                                                        Smart devices / home automation  0.112121
#                                     Smart devices / home automation                                                                                                          Telephones, smartphones, e-readers, wearables  0.113962

# %%
# Mean distance to all other categories (excludes self since diagonal is 0)
distance_means = dist_df.mean(axis=1).sort_values(ascending=False)

top_20_distinct = distance_means.head(20).reset_index()
top_20_distinct.columns = ['category', 'mean_distance']

print(top_20_distinct.to_string(index=False))
# Out:
#                                                              category  mean_distance
#                                Transformers, power supplies, chargers       0.755473
#                  Electrical devices for personal and recreational use       0.705138
#                                                  Household appliances       0.529241
#                                                        Gas appliances       0.458360
#                      Switches, plugs, sockets, connectors, switchgear       0.457769
#                                                 Recreational vehicles       0.455278
#                                                     Power electronics       0.443033
#                                                              Vehicles       0.426254
#                                                             Batteries       0.397364
#                                                                  Toys       0.368038
#                                         Measuring equipment (non-MID)       0.310500
# Televisions, monitors, projectors, LED screens and information kiosks       0.308238
#                                                             Machinery       0.286939
#                                                Energy storage systems       0.284612
#                                Measuring and weighing equipment (MID)       0.282227
#            Communication equipment / transmitting-receiving equipment       0.280267
#                                      Alarm and fire detection systems       0.276898
#                                           Printers, copiers, scanners       0.276552
#                      Input/output devices (keyboard, mouse, monitors)       0.274814
#                                                     Medical equipment       0.270243

# %%
import pandas as pd
import ast

df = pd.read_csv('datasets/labeled_vulnerabilities.csv')
df['description_cleaned'] = df['description_cleaned'].apply(ast.literal_eval)
df.head()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_4836\852171149.py:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('datasets/labeled_vulnerabilities.csv')
#                 id                                        description  \
# 0  EUVD-2026-24141  FreeScout is a free self-hosted help desk and ...
# 1  EUVD-2026-24138  Vulnerability related to an unquoted search pa...
# 2  EUVD-2026-24136  The method "sock_recvfrom_into()" of "asyncio....
# 3  EUVD-2026-24130  User‑Controlled HTTP Header in Fortra's GoAnyw...
# 4  EUVD-2026-24129  The login limit is not enforced on the SFTP se...
#
#               datePublished               dateUpdated  baseScoreVersion  \
# 0  Apr 21, 2026, 3:52:39 PM  Apr 21, 2026, 3:52:39 PM               3.1
# 1  Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM               4.0
# 2  Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM               4.0
# 3  Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM               3.1
# 4  Apr 21, 2026, 3:32:22 PM  Apr 21, 2026, 3:32:22 PM               3.1
#
#   exploitedSince                                    baseScoreVector  epss  \
# 0            NaN       CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N   0.0
# 1            NaN  CVSS:4.0/AV:L/AC:L/AT:N/PR:L/UI:N/VC:H/VI:H/VA...   0.0
# 2            NaN  CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:L/VI:L/VA...   0.0
# 3            NaN       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:L   0.0
# 4            NaN       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:L/A:L   0.0
#
#    assigner                               aliases  \
# 0  GitHub_M                      CVE-2026-40565\n
# 1    INCIBE  GHSA-9vxj-j2f7-9mgg\nCVE-2026-5789\n
# 2       PSF  GHSA-3p9c-22jr-wq4x\nCVE-2026-3298\n
# 3    Fortra  GHSA-6x5f-r479-qh4p\nCVE-2026-1089\n
# 4    Fortra  GHSA-rpc6-m3h5-gmf2\nCVE-2026-0972\n
#
#                                        enisaIdVendor  \
# 0  [{'id': 'df8ea7fe-ea1b-3f31-a494-89b12dbf0c16'...
# 1  [{'id': '5112208e-9449-3f30-b5a0-bdefa26b6740'...
# 2  [{'id': '455eddad-0274-38e3-876c-1da485aedea5'...
# 3  [{'id': '2ae1e1ad-e03a-3855-b5d6-a2176c0b31dd'...
# 4  [{'id': 'cba00c9f-fa23-3062-a6a5-5709e85421d7'...
#
#                                           references  \
# 0  https://github.com/freescout-help-desk/freesco...
# 1  https://www.incibe.es/en/incibe-cert/notices/a...
# 2  https://github.com/python/cpython/pull/148809\...
# 3  https://www.fortra.com/security/advisories/pro...
# 4  https://fortra.com/security/advisories/product...
#
#                                       enisaIdProduct  baseScore  \
# 0  [{'id': '35cc8fe9-cc82-3bc7-9dda-d8dfd8a9d826'...        6.1
# 1  [{'id': '4dd00402-1cb8-33d1-91f8-5daf0e5fa5c5'...        8.5
# 2  [{'id': '79323943-f5b6-3a59-ac3e-e7849e5be63e'...        8.8
# 3  [{'id': '70404ca1-7e53-3be1-87b1-6dc09b1e4ff2'...        6.5
# 4  [{'id': 'd104a637-0939-344c-be4c-448beede3920'...        7.3
#
#                               enisaUuid  \
# 0  b3a6ee31-e20e-3b1c-a684-768095acc098
# 1  7ed70757-c092-3a0b-99e2-96a7f815201b
# 2  e0f49fce-f7e8-3dfc-b70e-dbc0c058a383
# 3  f1bfb170-4572-33bb-a02c-83c7a5e4ce08
# 4  3965ce35-f611-3fd6-bc4c-580538b77705
#
#                                  description_cleaned    product_name  \
# 0  [freescout, free, selfhosted, help, desk, shar...       freescout
# 1  [vulnerability, related, unquoted, search, pat...        civetweb
# 2  [method, sock_recvfrom_into, asyncioproacterev...         CPython
# 3  [usercontrolled, http, header, fortras, goanyw...  GoAnywhere MFT
# 4  [login, limit, enforced, sftp, service, fortra...  GoAnywhere MFT
#
#                   vendor_name                                 product_label
# 0         freescout-help-desk         Customer Support & Help Desk Software
# 1                    CivetWeb                           Web Server Software
# 2  Python Software Foundation  Programming Language Runtimes & Interpreters
# 3                      Fortra          FTP & Managed File Transfer Software
# 4                      Fortra          FTP & Managed File Transfer Software

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary
import itertools

def get_top_words_per_topic(model, feature_names, n_words=10):
    topics = []
    for topic in model.components_:
        top_indices = topic.argsort()[:-n_words - 1:-1]
        topics.append([feature_names[i] for i in top_indices])
    return topics


def topic_diversity(topics):
    all_words = [w for topic in topics for w in topic]
    if not all_words:
        return 0.0
    return len(set(all_words)) / len(all_words)


def coherence_score(topics, tokenized_docs, dictionary):
    cm = CoherenceModel(
        topics=topics,
        texts=tokenized_docs,
        dictionary=dictionary,
        coherence='c_v',
    )
    return cm.get_coherence()

def print_topics(model, feature_names, n_words=10):
    for i, topic in enumerate(model.components_):
        top_words = [feature_names[j] for j in topic.argsort()[:-n_words - 1:-1]]
        print(f"Topic {i:02d}: {', '.join(top_words)}")

# %%
with open("lda_topics_all.txt", "w") as out:
    out.write("LDA Topic Results\n" + "="*60 + "\n\n")

to_check = ["Gaming Software & Game Engines"]
for category in to_check:
    print(f"Category: {category}")
    tokenized_docs = df[df["product_label"] == category]["description_cleaned"].tolist()
    texts = [" ".join(doc) for doc in tokenized_docs]

    count_vectorizer = CountVectorizer(
        max_df=0.5,
        min_df=10,
        max_features=50000,
        ngram_range=(1, 2),
        token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
        stop_words='english',
    )
    dtm_counts = count_vectorizer.fit_transform(texts)
    count_features = count_vectorizer.get_feature_names_out()

    gensim_dict = Dictionary(tokenized_docs)

    k_range = [10, 15, 20, 25, 30, 35, 40]
    alpha_range = [0.05, 0.1, 0.3]
    beta_range = [None, 0.01, 0.1]  # None = sklearn auto

    lda_results = []

    for k, alpha, beta in itertools.product(k_range, alpha_range, beta_range):
        lda = LatentDirichletAllocation(
            n_components=k,
            doc_topic_prior=alpha,
            topic_word_prior=beta,
            max_iter=20,
            learning_method='batch',
            random_state=1,
        )
        lda.fit(dtm_counts)

        topics = get_top_words_per_topic(lda, count_features, n_words=10)
        coherence = coherence_score(topics, tokenized_docs, gensim_dict)
        diversity = topic_diversity(topics)

        lda_results.append({
            'k': k,
            'alpha': alpha,
            'beta': beta,
            'coherence': coherence,
            'diversity': diversity,
            'combined_score': coherence * diversity, #to get a score between 0 and 1, with both contributing equally
        })
        print(f"k={k:>2} alpha={alpha} beta={beta}: "
            f"coherence={coherence:.4f} diversity={diversity:.3f}")

    lda_results_df = pd.DataFrame(lda_results).sort_values('combined_score', ascending=False)

    best_config = lda_results_df.iloc[0]
    best_beta = None if pd.isna(best_config['beta']) else best_config['beta']
    final_model = LatentDirichletAllocation(
        n_components=int(best_config['k']),
        doc_topic_prior=int(best_config['alpha']),
        topic_word_prior=int(best_beta) if best_beta is not None else None,
        max_iter=20,
        learning_method='batch',
        random_state=1,
    )
    final_model.fit(dtm_counts)
    
    
    print(f"Best configuration for category '{category}': k={best_config['k']}, alpha={best_config['alpha']}, beta={best_config['beta']}, coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, combined_score={best_config['combined_score']:.4f}")
    print_topics(final_model, count_features, n_words=10)
    
    with open("lda_topics_all.txt", "a") as out:
        out.write(f"Category: {category}\n")
        out.write(f"Best config: k={int(best_config['k'])}, alpha={best_config['alpha']}, beta={best_config['beta']}, "
                f"coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, "
                f"combined_score={best_config['combined_score']:.4f}\n\n")
        for i, topic in enumerate(final_model.components_):
            top_words = [count_features[j] for j in topic.argsort()[:-11:-1]]
            out.write(f"Topic {i:02d}: {', '.join(top_words)}\n")
        out.write("\n" + "-"*60 + "\n\n")
# Out:
# Category: Gaming Software & Game Engines
# k=10 alpha=0.05 beta=None: coherence=0.6095 diversity=0.740
# k=10 alpha=0.05 beta=0.01: coherence=0.6152 diversity=0.830
# k=10 alpha=0.05 beta=0.1: coherence=0.6095 diversity=0.740
# k=10 alpha=0.1 beta=None: coherence=0.5988 diversity=0.760
# k=10 alpha=0.1 beta=0.01: coherence=0.5812 diversity=0.780
# k=10 alpha=0.1 beta=0.1: coherence=0.5988 diversity=0.760
# k=10 alpha=0.3 beta=None: coherence=0.6224 diversity=0.790
# k=10 alpha=0.3 beta=0.01: coherence=0.5943 diversity=0.790
# k=10 alpha=0.3 beta=0.1: coherence=0.6224 diversity=0.790
# k=15 alpha=0.05 beta=None: coherence=0.6028 diversity=0.740
# k=15 alpha=0.05 beta=0.01: coherence=0.6139 diversity=0.740
# k=15 alpha=0.05 beta=0.1: coherence=0.6268 diversity=0.733
# k=15 alpha=0.1 beta=None: coherence=0.6048 diversity=0.727
# k=15 alpha=0.1 beta=0.01: coherence=0.6301 diversity=0.740
# k=15 alpha=0.1 beta=0.1: coherence=0.6121 diversity=0.740
# k=15 alpha=0.3 beta=None: coherence=0.5834 diversity=0.760
# k=15 alpha=0.3 beta=0.01: coherence=0.5692 diversity=0.773
# k=15 alpha=0.3 beta=0.1: coherence=0.5832 diversity=0.773
# k=20 alpha=0.05 beta=None: coherence=0.5863 diversity=0.665
# k=20 alpha=0.05 beta=0.01: coherence=0.5900 diversity=0.665
# k=20 alpha=0.05 beta=0.1: coherence=0.5670 diversity=0.665
# k=20 alpha=0.1 beta=None: coherence=0.5843 diversity=0.710
# k=20 alpha=0.1 beta=0.01: coherence=0.5967 diversity=0.690
# k=20 alpha=0.1 beta=0.1: coherence=0.5853 diversity=0.700
# k=20 alpha=0.3 beta=None: coherence=0.5919 diversity=0.725
# k=20 alpha=0.3 beta=0.01: coherence=0.5753 diversity=0.725
# k=20 alpha=0.3 beta=0.1: coherence=0.5790 diversity=0.740
# k=25 alpha=0.05 beta=None: coherence=0.5482 diversity=0.640
# k=25 alpha=0.05 beta=0.01: coherence=0.5501 diversity=0.660
# k=25 alpha=0.05 beta=0.1: coherence=0.5359 diversity=0.676
# k=25 alpha=0.1 beta=None: coherence=0.5380 diversity=0.632
# k=25 alpha=0.1 beta=0.01: coherence=0.5558 diversity=0.664
# k=25 alpha=0.1 beta=0.1: coherence=0.5264 diversity=0.660
# k=25 alpha=0.3 beta=None: coherence=0.5487 diversity=0.700
# k=25 alpha=0.3 beta=0.01: coherence=0.5338 diversity=0.712
# k=25 alpha=0.3 beta=0.1: coherence=0.5499 diversity=0.696
# k=30 alpha=0.05 beta=None: coherence=0.5868 diversity=0.603
# k=30 alpha=0.05 beta=0.01: coherence=0.6169 diversity=0.620
# k=30 alpha=0.05 beta=0.1: coherence=0.5565 diversity=0.597
# k=30 alpha=0.1 beta=None: coherence=0.5981 diversity=0.617
# k=30 alpha=0.1 beta=0.01: coherence=0.5912 diversity=0.637
# k=30 alpha=0.1 beta=0.1: coherence=0.5680 diversity=0.603
# k=30 alpha=0.3 beta=None: coherence=0.5419 diversity=0.720
# k=30 alpha=0.3 beta=0.01: coherence=0.5507 diversity=0.713
# k=30 alpha=0.3 beta=0.1: coherence=0.5641 diversity=0.703
# k=35 alpha=0.05 beta=None: coherence=0.5840 diversity=0.614
# k=35 alpha=0.05 beta=0.01: coherence=0.5991 diversity=0.626
# k=35 alpha=0.05 beta=0.1: coherence=0.5627 diversity=0.594
# k=35 alpha=0.1 beta=None: coherence=0.5866 diversity=0.631
# k=35 alpha=0.1 beta=0.01: coherence=0.5916 diversity=0.640
# k=35 alpha=0.1 beta=0.1: coherence=0.5866 diversity=0.614
# k=35 alpha=0.3 beta=None: coherence=0.6002 diversity=0.709
# k=35 alpha=0.3 beta=0.01: coherence=0.6195 diversity=0.717
# k=35 alpha=0.3 beta=0.1: coherence=0.5916 diversity=0.703
# k=40 alpha=0.05 beta=None: coherence=0.5954 diversity=0.580
# k=40 alpha=0.05 beta=0.01: coherence=0.5964 diversity=0.593
# k=40 alpha=0.05 beta=0.1: coherence=0.5514 diversity=0.595
# k=40 alpha=0.1 beta=None: coherence=0.5297 diversity=0.590
# k=40 alpha=0.1 beta=0.01: coherence=0.5412 diversity=0.585
# k=40 alpha=0.1 beta=0.1: coherence=0.5451 diversity=0.595
# k=40 alpha=0.3 beta=None: coherence=0.5500 diversity=0.693
# k=40 alpha=0.3 beta=0.01: coherence=0.5673 diversity=0.695
# k=40 alpha=0.3 beta=0.1: coherence=0.5677 diversity=0.675
# Best configuration for category 'Gaming Software & Game Engines': k=10.0, alpha=0.05, beta=0.01, coherence=0.6152, diversity=0.830, combined_score=0.5106
# Topic 00: authentication, prior, openclaw version, gateway, version prior, bypass, contain, prior contain, access, allowing
# Topic 01: webhook, request, endpoint, unauthenticated, token, event, telegram, server, post, fixed
# Topic 02: command, bypass, openclaw version, prior, approval, version prior, allowlist, contain, prior contain, bypass vulnerability
# Topic 03: code, execution, arbitrary, execute, local, malicious, file, privilege, code execution, execute arbitrary
# Topic 04: issue, affect, issue affect, bot, information, user, client, override, result, key
# Topic 05: assistant, personal, openclaw personal, personal assistant, prior, access, tool, issue, assistant prior, prior version
# Topic 06: authorization, contains, openclaw contains, bypass, access, scope, exploit, privilege, session, attacker exploit
# Topic 07: file, path, directory, outside, traversal, sandbox, write, read, arbitrary, path traversal
# Topic 08: manipulation, affected, attack, issue, patch, sql, lead, file, injection, identifier
# Topic 09: user, buffer, game, overflow, application, crash, buffer overflow, memory, code, cause
# C:\Users\kevin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\decomposition\_lda.py:805: RuntimeWarning: invalid value encountered in multiply
#   score = np.sum((prior - distr) * dirichlet_distr)
# C:\Users\kevin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\decomposition\_lda.py:806: RuntimeWarning: invalid value encountered in subtract
#   score += np.sum(gammaln(distr) - gammaln(prior))

# %%
# For failed models manually
tokenized_docs_1 = df[df["product_label"] == "PDF & Document Viewer/Editor Software"]["description_cleaned"].tolist()
texts_1 = [" ".join(doc) for doc in tokenized_docs_1]

count_vectorizer_1 = CountVectorizer(
    max_df=0.5,
    min_df=10,
    max_features=50000,
    ngram_range=(1, 2),
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
    stop_words='english',
)
dtm_counts_1 = count_vectorizer_1.fit_transform(texts_1)
count_features_1 = count_vectorizer_1.get_feature_names_out()

final_model_1 = LatentDirichletAllocation(
    n_components=10,
    doc_topic_prior=0.3,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
final_model_1.fit(dtm_counts_1)
    

print(f"Best configuration for category '{category}': k={best_config['k']}, alpha={best_config['alpha']}, beta={best_config['beta']}, coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, combined_score={best_config['combined_score']:.4f}")
print_topics(final_model_1, count_features_1, n_words=10)

with open("lda_topics_all.txt", "a") as out:
    out.write(f"Category: {category}\n")
    out.write(f"Best config: k={int(best_config['k'])}, alpha={best_config['alpha']}, beta={best_config['beta']}, "
            f"coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, "
            f"combined_score={best_config['combined_score']:.4f}\n\n")
    for i, topic in enumerate(final_model_1.components_):
        top_words = [count_features_1[j] for j in topic.argsort()[:-11:-1]]
        out.write(f"Topic {i:02d}: {', '.join(top_words)}\n")
    out.write("\n" + "-"*60 + "\n\n")
# Out:
# Best configuration for category 'Legal, Compliance & Privacy Management Software': k=10.0, alpha=0.1, beta=nan, coherence=0.7060, diversity=0.800, combined_score=0.5648
# Topic 00: read, result read, read past, outofbounds read, outofbounds, allocated, end, past end, past, end allocated
# Topic 01: earlier, bypass, earlier earlier, memory, vulnerability bypass, aslr, aslr exploitation, mitigation aslr, mitigation, bypass mitigation
# Topic 02: execute, remote, flaw, installation, vulnerability allows, execute code, target, specific flaw, flaw exists, data
# Topic 03: trigger, trigger vulnerability, pdf, foxit, crafted, specially, specially crafted, vulnerability exists, document, file trigger
# Topic 04: information, pdf, read, sensitive information, disclose, sensitive, disclose sensitive, attacker disclose, conjunction vulnerability, conjunction
# Topic 05: earlier, earlier earlier, version, acrobat, version earlier, earlier affected, exploitation, exploitation issue, requires user, requires
# Topic 06: object, execute, foxit, remote, foxit pdf, pdf reader, pdf, operation, performing, target
# Topic 07: pdf, pdf file, privilege, version, crafted, path, application, allows, local, service
# Topic 08: earlier, earlier earlier, version, acrobat, acrobat reader, version earlier, reader version, earlier affected, current user, victim
# Topic 09: pdf, power, power pdf, parsing, kofax, kofax power, remote, execute, pdf user, file parsing

# %%
# For failed models manually
tokenized_docs_1 = df[df["product_label"] == "PDF & Document Viewer/Editor Software"]["description_cleaned"].tolist()
texts_1 = [" ".join(doc) for doc in tokenized_docs_1]

count_vectorizer_1 = CountVectorizer(
    max_df=0.5,
    min_df=10,
    max_features=50000,
    ngram_range=(1, 2),
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
    stop_words='english',
)
dtm_counts_1 = count_vectorizer_1.fit_transform(texts_1)
count_features_1 = count_vectorizer_1.get_feature_names_out()

final_model_1 = LatentDirichletAllocation(
    n_components=10,
    doc_topic_prior=0.3,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
final_model_1.fit(dtm_counts_1)
    

print(f"Best configuration for category '{category}': k={best_config['k']}, alpha={best_config['alpha']}, beta={best_config['beta']}, coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, combined_score={best_config['combined_score']:.4f}")
print_topics(final_model_1, count_features_1, n_words=10)

with open("lda_topics_all.txt", "a") as out:
    out.write(f"Category: {category}\n")
    out.write(f"Best config: k={int(best_config['k'])}, alpha={best_config['alpha']}, beta={best_config['beta']}, "
            f"coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, "
            f"combined_score={best_config['combined_score']:.4f}\n\n")
    for i, topic in enumerate(final_model_1.components_):
        top_words = [count_features_1[j] for j in topic.argsort()[:-11:-1]]
        out.write(f"Topic {i:02d}: {', '.join(top_words)}\n")
    out.write("\n" + "-"*60 + "\n\n")

# %%
# For failed models manually
tokenized_docs_2 = df[df["product_label"] == "Web Server Software"]["description_cleaned"].tolist()
texts_2 = [" ".join(doc) for doc in tokenized_docs_2]

count_vectorizer_2 = CountVectorizer(
    max_df=0.5,
    min_df=10,
    max_features=50000,
    ngram_range=(1, 2),
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
    stop_words='english',
)
dtm_counts_2 = count_vectorizer_2.fit_transform(texts_2)
count_features_2 = count_vectorizer_2.get_feature_names_out()

final_model_2 = LatentDirichletAllocation(
    n_components=15,
    doc_topic_prior=0.1,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
final_model_2.fit(dtm_counts_2)
    

print(f"Best configuration for category '{category}': k={best_config['k']}, alpha={best_config['alpha']}, beta={best_config['beta']}, coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, combined_score={best_config['combined_score']:.4f}")
print_topics(final_model_2, count_features_2, n_words=10)

with open("lda_topics_all.txt", "a") as out:
    out.write(f"Category: {category}\n")
    out.write(f"Best config: k={int(best_config['k'])}, alpha={best_config['alpha']}, beta={best_config['beta']}, "
            f"coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, "
            f"combined_score={best_config['combined_score']:.4f}\n\n")
    for i, topic in enumerate(final_model_2.components_):
        top_words = [count_features_2[j] for j in topic.argsort()[:-11:-1]]
        out.write(f"Topic {i:02d}: {', '.join(top_words)}\n")
    out.write("\n" + "-"*60 + "\n\n")
# Out:
# Best configuration for category 'Legal, Compliance & Privacy Management Software': k=10.0, alpha=0.1, beta=nan, coherence=0.7060, diversity=0.800, combined_score=0.5648
# Topic 00: request, header, http, puma, proxy, response, fixed, http request, client, attacker
# Topic 01: access, allows, web, affect, web server, attacker, issue, issue affect, cache, application
# Topic 02: apache, http, http server, apache http, issue, fix, upgrade, user, recommended, user recommended
# Topic 03: attacker, remote, allows, code, arbitrary, execute, privilege, service, malicious, remote attacker
# Topic 04: file, path, directory, web, web server, traversal, path traversal, allows, information, patch
# Topic 05: user, allow, send, remote, remote user, allow remote, crafted, specially crafted, specially, affecting
# Topic 06: connection, service, denial service, denial, request, thread, remote, web, web server, attacker
# Topic 07: command, injection, code, command injection, improper, arbitrary, allows, control, code execution, execution
# Topic 08: use, user, code, url, affected, script, configuration, apache, enabled, authentication
# Topic 09: oracle, http, http server, oracle http, access, data, cvss, unauthorized, accessible, attack
# Topic 10: crosssite, crosssite scripting, scripting, prior, github, repository, github repository, xss, repository hestiacphestiacp, hestiacphestiacp
# Topic 11: prior, version prior, prior version, buffer, default, path, issue, request, file, application
# Topic 12: nginx, module, file, memory, attacker, used, worker, client, cause, process
# Topic 13: exploit, disclosed, used, remotely exploit, exploit disclosed, public used, disclosed public, public, remotely, manipulation
# Topic 14: issue, classified, lead, patch, unknown, component, file, affect, affected, manipulation

# %%
# For failed models manually
tokenized_docs_3 = df[df["product_label"] == "Wearable & Consumer Electronics"]["description_cleaned"].tolist()
texts_3 = [" ".join(doc) for doc in tokenized_docs_3]

count_vectorizer_3 = CountVectorizer(
    max_df=0.5,
    min_df=10,
    max_features=50000,
    ngram_range=(1, 2),
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z0-9_\-]{2,}\b",
    stop_words='english',
)
dtm_counts_3 = count_vectorizer_3.fit_transform(texts_3)
count_features_3 = count_vectorizer_3.get_feature_names_out()

final_model_3 = LatentDirichletAllocation(
    n_components=30,
    doc_topic_prior=0.1,
    topic_word_prior=None,
    max_iter=20,
    learning_method='batch',
    random_state=1,
)
final_model_3.fit(dtm_counts_3)
    

print(f"Best configuration for category '{category}': k={best_config['k']}, alpha={best_config['alpha']}, beta={best_config['beta']}, coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, combined_score={best_config['combined_score']:.4f}")
print_topics(final_model_3, count_features_3, n_words=10)

with open("lda_topics_all.txt", "a") as out:
    out.write(f"Category: {category}\n")
    out.write(f"Best config: k={int(best_config['k'])}, alpha={best_config['alpha']}, beta={best_config['beta']}, "
            f"coherence={best_config['coherence']:.4f}, diversity={best_config['diversity']:.3f}, "
            f"combined_score={best_config['combined_score']:.4f}\n\n")
    for i, topic in enumerate(final_model_3.components_):
        top_words = [count_features_3[j] for j in topic.argsort()[:-11:-1]]
        out.write(f"Topic {i:02d}: {', '.join(top_words)}\n")
    out.write("\n" + "-"*60 + "\n\n")
# Out:
# Best configuration for category 'Legal, Compliance & Privacy Management Software': k=10.0, alpha=0.1, beta=nan, coherence=0.7060, diversity=0.800, combined_score=0.5648
# Topic 00: firmware, update, http, firmware update, server, exploitable, request, device, vulnerability exists, exists
# Topic 01: attack, lead, component, manipulation, unknown, manipulation lead, vendor, disclosure, contacted, early
# Topic 02: service, allows attacker, improper, denial, denial service, smr oct2021, oct2021, oct2021 release, mar2022, mar2022 release
# Topic 03: apr2022 release, apr2022, smr apr2022, library, library prior, function, bound, libsimba library, libsimba, remote attacker
# Topic 04: information, sensitive, sensitive information, local attacker, local, access, allows local, attacker access, exposure, exposure sensitive
# Topic 05: execute, code, specific, result, sonos, vulnerability allows, exploit, data, exploit vulnerability, flaw
# Topic 06: access, control, access control, improper access, improper, local, local attacker, allows local, control vulnerability, attacker access
# Topic 07: outofbounds, memory, write, allows local, local, read, outofbounds memory, trustlet, trustlet prior, local attacker
# Topic 08: check, logic, file, service, command, affected, exploitation, size, successful, check logic
# Topic 09: intent, allows attacker, implicit, implicit intent, hijacking, hijacking vulnerability, improper, certain, activity, improper validation
# Topic 10: privilege, local, cause, local attacker, attacker cause, management, allows local, privilege management, improper privilege, improper
# Topic 11: jun2022 release, smr jun2022, jun2022, allows attacker, sep2021 release, sep2021, smr sep2021, pointer, read, file
# Topic 12: user, interaction, user interaction, triggering, triggering vulnerability, required triggering, required, interaction required, smr jul2024, jul2024
# Topic 13: authorization, improper authorization, permission, improper, setting, allows attacker, setting prior, jan2023 release, smr jan2023, jan2023
# Topic 14: validation, input, input validation, improper input, improper, validation vulnerability, allows attacker, arbitrary, may2021 release, may2021
# Topic 15: application, untrusted, untrusted application, allows untrusted, proper, proper permission, unprotected, application prior, mobile, feb2024 release
# Topic 16: bluetooth, aug2022, smr aug2022, aug2022 release, address, mac, mac address, device, leak, connected
# Topic 17: version, allows attacker, access, wifi, version allows, prior version, samsung, information, vulnerability samsung, dex
# Topic 18: execution, code, code execution, buffer, arbitrary, overflow, buffer overflow, heapbased, heapbased buffer, execution vulnerability
# Topic 19: allows local, local, local attacker, improper, handling, insufficient, improper handling, permission, insufficient permission, handling insufficient
# Topic 20: overflow, buffer, buffer overflow, network, request, send, attacker send, trigger, overflow vulnerability, network request
# Topic 21: execute, attacker execute, arbitrary, execute arbitrary, smr jul2023, jul2023 release, jul2023, arbitrary code, code, allows local
# Topic 22: allows attacker, memory, driver, driver prior, attacker cause, smr sep2022, sep2022 release, sep2022, use, cause
# Topic 23: execute, code, arbitrary, arbitrary code, outofbounds, execute arbitrary, outofbounds write, attacker execute, allows local, local
# Topic 24: remote, remote attacker, allows remote, smr apr2023, apr2023 release, apr2023, malicious, process, network, code
# Topic 25: activity, launch, attacker launch, local attacker, local, allows local, sep2023 release, sep2023, smr sep2023, privileged activity
# Topic 26: physical, physical attacker, allows physical, improper, authentication, bypass, access, secure, improper authentication, folder
# Topic 27: file, arbitrary, path, arbitrary file, traversal, path traversal, traversal vulnerability, smr nov2023, nov2023, nov2023 release
# Topic 28: allow, reported, vulnerability reported, allow local, application, local, device, motorola, reported motorola, application allow
# Topic 29: android, improper, application, file, access, export, local, improper export, local attacker, attacker access
